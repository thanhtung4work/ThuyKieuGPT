# %%
import tensorflow as tf

import numpy as np
import os
import time
import re
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Preprocess data

# %%
# Read, then decode for py2 compat.
text = open("data/tale of kieu.txt", 'rb').read().decode(encoding='utf-8')
# length of text is the number of characters in it
print(f'Length of text: {len(text)} characters')
# Out:
# Length of text: 110585 characters

# %%
print(text[:200])
# Out:
# 1.Trăm năm trong cõi người ta,
# Chữ tài chữ mệnh khéo là ghét nhau.
# Trải qua một cuộc bể dâu,
# Những điều trông thấy mà đau đớn lòng.
# 5.Lạ gì bỉ sắc tư phong,
# Trời xanh quen thói má hồng đánh ghen.

# %%
text = re.sub(r'[0-9]+.', '', text.lower())
text = re.sub(r'[\.,!?;()-]', '', text.lower())

# %%
print(text[:250])
# Out:
# trăm năm trong cõi người ta
# chữ tài chữ mệnh khéo là ghét nhau
# trải qua một cuộc bể dâu
# những điều trông thấy mà đau đớn lòng
# lạ gì bỉ sắc tư phong
# trời xanh quen thói má hồng đánh ghen
# cảo thơm lần giở trước đèn
# phong tình cổ lục còn truyền s

# %%
# get unique characters from origin text
vocab = sorted(set(text))
print(f'{len(vocab)} unique characters')
# Out:
# 92 unique characters

# %%
sample_text = ['I am batman', 'i am ironman']
chars = tf.strings.unicode_split(sample_text, input_encoding='UTF-8')
chars
# Out:
# <tf.RaggedTensor [[b'I', b' ', b'a', b'm', b' ', b'b', b'a', b't', b'm', b'a', b'n'],
#  [b'i', b' ', b'a', b'm', b' ', b'i', b'r', b'o', b'n', b'm', b'a', b'n']]>

# %%
# convert characters to numeric id
idxs_from_chars = tf.keras.layers.StringLookup(
    vocabulary = list(vocab), mask_token=None
)

# %%
idxs = idxs_from_chars(chars)
idxs
# Out:
# <tf.RaggedTensor [[0, 3, 5, 15, 3, 6, 5, 22, 15, 5, 16],
#  [12, 3, 5, 15, 3, 12, 20, 17, 16, 15, 5, 16]]>

# %%
chars_from_idxs = tf.keras.layers.StringLookup(
    vocabulary = idxs_from_chars.get_vocabulary(), invert=True, mask_token=None
)

# %%
chars = chars_from_idxs(idxs)
chars
# Out:
# <tf.RaggedTensor [[b'[UNK]', b' ', b'a', b'm', b' ', b'b', b'a', b't', b'm', b'a', b'n'],
#  [b'i', b' ', b'a', b'm', b' ', b'i', b'r', b'o', b'n', b'm', b'a', b'n']]>

# %%
def text_from_idxs(idxs):
    return tf.strings.reduce_join(chars_from_idxs(idxs), axis=-1)

# %%
sample_text = text_from_idxs(idxs)
sample_text
# Out:
# <tf.Tensor: shape=(2,), dtype=string, numpy=array([b'[UNK] am batman', b'i am ironman'], dtype=object)>

# %%
all_idxs = idxs_from_chars(tf.strings.unicode_split(text, input_encoding='UTF-8'))
all_idxs
# Out:
# <tf.Tensor: shape=(104095,), dtype=int64, numpy=array([22, 20, 43, ...,  5, 16, 11])>

# %%
idxs_dataset = tf.data.Dataset.from_tensor_slices(all_idxs)

# %%
SEQ_LENGTH = 100

# %%
sequences = idxs_dataset.batch(SEQ_LENGTH + 1, drop_remainder=True)

# %%
for seq in sequences.take(5):
    print(text_from_idxs(seq).numpy().decode('utf-8'))
    print("===")
# Out:
# trăm năm trong cõi người ta
# chữ tài chữ mệnh khéo là ghét nhau
# trải qua một cuộc bể dâu
# những điều
# ===
#  trông thấy mà đau đớn lòng
# lạ gì bỉ sắc tư phong
# trời xanh quen thói má hồng đánh ghen
# cảo thơm l
# ===
# ần giở trước đèn
# phong tình cổ lục còn truyền sử xanh
# rằng năm gia tĩnh triều minh
# bốn phương phẳn
# ===
# g lặng hai kinh vững vàng
# có nhà viên ngoại họ vương
# gia tư nghĩ cũng thường thường bực trung
# một
# ===
# trai con thứ rốt lòng
# vương quan là chữ nối dòng nho gia
# đầu lòng hai ả tố nga
# thúy kiều là chị em
# ===

# %%
def split_input_target(sequence):
    input = sequence[:-1]
    target = sequence[1:]
    return input, target

# %%
split_input_target('i am batman')
# Out:
# ('i am batma', ' am batman')

# %%
dataset = sequences.map(split_input_target)
for input_example, target_example in dataset.take(1):
    print("Input :", text_from_idxs(input_example).numpy().decode('utf-8'))
    print("Target:", text_from_idxs(target_example).numpy().decode('utf-8'))
# Out:
# Input : trăm năm trong cõi người ta
# chữ tài chữ mệnh khéo là ghét nhau
# trải qua một cuộc bể dâu
# những điề
# Target: răm năm trong cõi người ta
# chữ tài chữ mệnh khéo là ghét nhau
# trải qua một cuộc bể dâu
# những điều

# %%
# Batch size
BATCH_SIZE = 64

VOCAB_SIZE = len(idxs_from_chars.get_vocabulary())  # vocab is number of unique characters
EMBEDDING_DIM = 256
RNN_UNITS = 1024

# Buffer size to shuffle the dataset
# (TF data is designed to work with possibly infinite sequences,
# so it doesn't attempt to shuffle the entire sequence in memory. Instead,
# it maintains a buffer in which it shuffles elements).
BUFFER_SIZE = 10000

dataset = (
    dataset
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE))

dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(64, 100), dtype=tf.int64, name=None), TensorSpec(shape=(64, 100), dtype=tf.int64, name=None))>

# %% [markdown]
# # Build model

# %%
# Build model
class KieuModel(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, rnn_units):
        super().__init__(self)
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.lstm_0 = tf.keras.layers.LSTM(
            rnn_units,
            return_sequences=True,
            return_state=True
        )
        self.dense_0 = tf.keras.layers.Dense(1024)
        self.dropout_0 = tf.keras.layers.Dropout(0.3)
        self.dense_1 = tf.keras.layers.Dense(512)
        self.dropout_1 = tf.keras.layers.Dropout(0.3)
        self.dense_2 = tf.keras.layers.Dense(vocab_size)

    def call(self, inputs, states=None, return_state=False, training=False):
        x = inputs
        x = self.embedding(x, training=training)
        # LSTM 1
        if states == None:
            state_h, state_c = self.lstm_0.get_initial_state(x)
            states = [state_h, state_c]
        x, state_h, state_c = self.lstm_0(x, initial_state=states, training=training)
        # FC
        x = self.dense_0(x, training=training)
        x = self.dropout_0(x)
        x = self.dense_1(x, training=training)
        x = self.dropout_1(x)
        x = self.dense_2(x, training=training)

        if return_state:
            return x, [state_h, state_c]
        else:
            return x

# %%
model = KieuModel(
    vocab_size=VOCAB_SIZE, embedding_dim=EMBEDDING_DIM, rnn_units=RNN_UNITS
)

# %%
for input_example, target_example in dataset.take(1):
    example_prediction = model(input_example)
    print(input_example)
# Out:
# tf.Tensor(
# [[30  3 22 ... 64 22  3]
#  [11 48 47 ... 16 11  2]
#  [12  3 14 ...  1 51 26]
#  ...
#  [10  3 22 ...  1 16 27]
#  [10 49 12 ... 21 52 23]
#  [ 3 22 79 ...  7 11 58]], shape=(64, 100), dtype=int64)

# %%
model.summary()
# Out:
# Model: "kieu_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       multiple                  23808
#
#  lstm (LSTM)                 multiple                  5246976
#
#  dense (Dense)               multiple                  1049600
#
#  dropout (Dropout)           multiple                  0
#
#  dense_1 (Dense)             multiple                  524800
#
#  dropout_1 (Dropout)         multiple                  0
#
#  dense_2 (Dense)             multiple                  47709
#
# =================================================================
# Total params: 6,892,893
# Trainable params: 6,892,893
# Non-trainable params: 0
# _________________________________________________________________

# %%
# To get actual predictions from the model you need to sample from the output distribution
sampled_indices = tf.random.categorical(example_prediction[0], num_samples=1)
sampled_indices = tf.squeeze(sampled_indices, axis=-1).numpy()
sampled_indices
# Out:
# array([ 0, 11, 33, 29, 42, 46, 82, 20, 41, 83, 61, 74, 10,  6, 60, 73, 35,
#        16, 44, 58, 59, 92, 65, 31, 56, 24, 16, 34, 80, 40, 29, 29, 46,  9,
#        77, 19, 21, 16, 80,  9, 11, 89, 90, 73, 58, 92, 15, 60,  8, 39, 10,
#        26, 62, 88, 49, 18, 83, 80, 87, 32, 60,  3, 91, 30, 82, 69, 50, 22,
#        46, 25,  7, 72, 56, 91, 20, 14,  1, 16, 21, 34, 67, 65, 16, 50, 50,
#        79, 84, 74, 50, 12, 51, 55, 53, 66, 75, 24, 26, 82,  3, 17])

# %%
print("Input:\n", text_from_idxs(input_example[0]).numpy().decode('utf-8'))
print()
print("Next Char Predictions:\n", text_from_idxs(sampled_indices).numpy().decode('utf-8'))
# Out:
# Input:
#  ã thẹn nàng oanh
# lại thua ả lý bán mình hay sao
# cỗi xuân tuổi hạc càng cao
# một cây gánh vác biết
#
# Next Char Predictions:
#  [UNK]hêâýũợrúụẹồgbặốínđẳẵỹềèắvnìởùââũeộqsnởehựỳốẳỹmặdõgyẻữạpụởửéặ ỷãợỉảtũxcỏắỷrl
# nsìễềnảảờủồảiấậẩểổvyợ o

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.0001), loss=loss)

# %%
def scheduler(epoch, lr):
    if epoch > 1000 and (epoch % 100) == 0:
        return lr * 0.5
    else:
        return lr

# %%
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
history = model.fit(dataset, epochs=2000, verbose=2)
# Out:
# Epoch 1/2000
# 16/16 - 6s - loss: 4.3216 - 6s/epoch - 385ms/step
# Epoch 2/2000
# 16/16 - 1s - loss: 3.7216 - 1s/epoch - 74ms/step
# Epoch 3/2000
# 16/16 - 1s - loss: 3.5616 - 1s/epoch - 65ms/step
# Epoch 4/2000
# 16/16 - 1s - loss: 3.5004 - 1s/epoch - 65ms/step
# Epoch 5/2000
# 16/16 - 1s - loss: 3.4593 - 1s/epoch - 65ms/step
# Epoch 6/2000
# 16/16 - 1s - loss: 3.4140 - 1s/epoch - 65ms/step
# Epoch 7/2000
# 16/16 - 1s - loss: 3.3406 - 1s/epoch - 66ms/step
# Epoch 8/2000
# 16/16 - 1s - loss: 3.2289 - 1s/epoch - 66ms/step
# Epoch 9/2000
# 16/16 - 1s - loss: 3.0924 - 1s/epoch - 73ms/step
# Epoch 10/2000
# 16/16 - 1s - loss: 2.9518 - 1s/epoch - 66ms/step
# Epoch 11/2000
# 16/16 - 1s - loss: 2.8156 - 1s/epoch - 65ms/step
# Epoch 12/2000
# 16/16 - 1s - loss: 2.7232 - 1s/epoch - 65ms/step
# Epoch 13/2000
# 16/16 - 1s - loss: 2.6562 - 1s/epoch - 64ms/step
# Epoch 14/2000
# 16/16 - 1s - loss: 2.5911 - 1s/epoch - 65ms/step
# Epoch 15/2000
# 16/16 - 1s - loss: 2.5469 - 1s/epoch - 65ms/step
# Epoch 16/2000
# 16/16 - 1s - loss: 2.4761 - 1s/epoch - 65ms/step
# Epoch 17/2000
# 16/16 - 1s - loss: 2.4186 - 1s/epoch - 74ms/step
# Epoch 18/2000
# 16/16 - 1s - loss: 2.4116 - 1s/epoch - 65ms/step
# Epoch 19/2000
# 16/16 - 1s - loss: 2.3489 - 1s/epoch - 65ms/step
# Epoch 20/2000
# 16/16 - 1s - loss: 2.3124 - 1s/epoch - 65ms/step
# Epoch 21/2000
# 16/16 - 1s - loss: 2.2815 - 1s/epoch - 65ms/step
# Epoch 22/2000
# 16/16 - 1s - loss: 2.2540 - 1s/epoch - 65ms/step
# Epoch 23/2000
# 16/16 - 1s - loss: 2.2282 - 1s/epoch - 65ms/step
# Epoch 24/2000
# 16/16 - 1s - loss: 2.2077 - 1s/epoch - 65ms/step
# Epoch 25/2000
# 16/16 - 1s - loss: 2.1921 - 1s/epoch - 65ms/step
# Epoch 26/2000
# 16/16 - 1s - loss: 2.1691 - 1s/epoch - 66ms/step
# Epoch 27/2000
# 16/16 - 1s - loss: 2.1551 - 1s/epoch - 73ms/step
# Epoch 28/2000
# 16/16 - 1s - loss: 2.1426 - 1s/epoch - 65ms/step
# Epoch 29/2000
# 16/16 - 1s - loss: 2.1301 - 1s/epoch - 64ms/step
# Epoch 30/2000
# 16/16 - 1s - loss: 2.1124 - 1s/epoch - 65ms/step
# Epoch 31/2000
# 16/16 - 1s - loss: 2.0983 - 1s/epoch - 65ms/step
# Epoch 32/2000
# 16/16 - 1s - loss: 2.1012 - 1s/epoch - 65ms/step
# Epoch 33/2000
# 16/16 - 1s - loss: 2.0779 - 1s/epoch - 64ms/step
# Epoch 34/2000
# 16/16 - 1s - loss: 2.0679 - 1s/epoch - 65ms/step
# Epoch 35/2000
# 16/16 - 1s - loss: 2.0572 - 1s/epoch - 65ms/step
# Epoch 36/2000
# 16/16 - 1s - loss: 2.0524 - 1s/epoch - 65ms/step
# Epoch 37/2000
# 16/16 - 1s - loss: 2.0424 - 1s/epoch - 64ms/step
# Epoch 38/2000
# 16/16 - 1s - loss: 2.0379 - 1s/epoch - 65ms/step
# Epoch 39/2000
# 16/16 - 1s - loss: 2.0251 - 1s/epoch - 65ms/step
# Epoch 40/2000
# 16/16 - 1s - loss: 2.0231 - 1s/epoch - 65ms/step
# Epoch 41/2000
# 16/16 - 1s - loss: 2.0157 - 1s/epoch - 66ms/step
# Epoch 42/2000
# 16/16 - 1s - loss: 2.0071 - 1s/epoch - 66ms/step
# Epoch 43/2000
# 16/16 - 1s - loss: 1.9994 - 1s/epoch - 65ms/step
# Epoch 44/2000
# 16/16 - 1s - loss: 1.9945 - 1s/epoch - 65ms/step
# Epoch 45/2000
# 16/16 - 1s - loss: 1.9881 - 1s/epoch - 65ms/step
# Epoch 46/2000
# 16/16 - 1s - loss: 1.9829 - 1s/epoch - 65ms/step
# Epoch 47/2000
# 16/16 - 1s - loss: 1.9779 - 1s/epoch - 64ms/step
# Epoch 48/2000
# 16/16 - 1s - loss: 1.9707 - 1s/epoch - 65ms/step
# Epoch 49/2000
# 16/16 - 1s - loss: 1.9659 - 1s/epoch - 65ms/step
# Epoch 50/2000
# 16/16 - 1s - loss: 1.9583 - 1s/epoch - 65ms/step
# Epoch 51/2000
# 16/16 - 1s - loss: 1.9503 - 1s/epoch - 64ms/step
# Epoch 52/2000
# 16/16 - 1s - loss: 1.9463 - 1s/epoch - 65ms/step
# Epoch 53/2000
# 16/16 - 1s - loss: 1.9438 - 1s/epoch - 65ms/step
# Epoch 54/2000
# 16/16 - 1s - loss: 1.9371 - 1s/epoch - 65ms/step
# Epoch 55/2000
# 16/16 - 1s - loss: 1.9291 - 1s/epoch - 66ms/step
# Epoch 56/2000
# 16/16 - 1s - loss: 1.9262 - 1s/epoch - 72ms/step
# Epoch 57/2000
# 16/16 - 1s - loss: 1.9216 - 1s/epoch - 65ms/step
# Epoch 58/2000
# 16/16 - 1s - loss: 1.9193 - 1s/epoch - 65ms/step
# Epoch 59/2000
# 16/16 - 1s - loss: 1.9149 - 1s/epoch - 65ms/step
# Epoch 60/2000
# 16/16 - 1s - loss: 1.9110 - 1s/epoch - 65ms/step
# Epoch 61/2000
# 16/16 - 1s - loss: 1.9060 - 1s/epoch - 65ms/step
# Epoch 62/2000
# 16/16 - 1s - loss: 1.8990 - 1s/epoch - 65ms/step
# Epoch 63/2000
# 16/16 - 1s - loss: 1.8931 - 1s/epoch - 69ms/step
# Epoch 64/2000
# 16/16 - 1s - loss: 1.8913 - 1s/epoch - 65ms/step
# Epoch 65/2000
# 16/16 - 1s - loss: 1.8865 - 1s/epoch - 65ms/step
# Epoch 66/2000
# 16/16 - 1s - loss: 1.8844 - 1s/epoch - 66ms/step
# Epoch 67/2000
# 16/16 - 1s - loss: 1.8752 - 1s/epoch - 65ms/step
# Epoch 68/2000
# 16/16 - 1s - loss: 1.8725 - 1s/epoch - 65ms/step
# Epoch 69/2000
# 16/16 - 1s - loss: 1.8703 - 1s/epoch - 65ms/step
# Epoch 70/2000
# 16/16 - 1s - loss: 1.8676 - 1s/epoch - 65ms/step
# Epoch 71/2000
# 16/16 - 1s - loss: 1.8638 - 1s/epoch - 65ms/step
# Epoch 72/2000
# 16/16 - 1s - loss: 1.8569 - 1s/epoch - 65ms/step
# Epoch 73/2000
# 16/16 - 1s - loss: 1.8544 - 1s/epoch - 64ms/step
# Epoch 74/2000
# 16/16 - 1s - loss: 1.8514 - 1s/epoch - 65ms/step
# Epoch 75/2000
# 16/16 - 1s - loss: 1.8515 - 1s/epoch - 65ms/step
# Epoch 76/2000
# 16/16 - 1s - loss: 1.8439 - 1s/epoch - 73ms/step
# Epoch 77/2000
# 16/16 - 1s - loss: 1.8435 - 1s/epoch - 65ms/step
# Epoch 78/2000
# 16/16 - 1s - loss: 1.8377 - 1s/epoch - 66ms/step
# Epoch 79/2000
# 16/16 - 1s - loss: 1.8325 - 1s/epoch - 64ms/step
# Epoch 80/2000
# 16/16 - 1s - loss: 1.8299 - 1s/epoch - 65ms/step
# Epoch 81/2000
# 16/16 - 1s - loss: 1.8296 - 1s/epoch - 65ms/step
# Epoch 82/2000
# 16/16 - 1s - loss: 1.8240 - 1s/epoch - 65ms/step
# Epoch 83/2000
# 16/16 - 1s - loss: 1.8214 - 1s/epoch - 66ms/step
# Epoch 84/2000
# 16/16 - 1s - loss: 1.8160 - 1s/epoch - 72ms/step
# Epoch 85/2000
# 16/16 - 1s - loss: 1.8152 - 1s/epoch - 65ms/step
# Epoch 86/2000
# 16/16 - 1s - loss: 1.8094 - 1s/epoch - 65ms/step
# Epoch 87/2000
# 16/16 - 1s - loss: 1.8076 - 1s/epoch - 65ms/step
# Epoch 88/2000
# 16/16 - 1s - loss: 1.8058 - 1s/epoch - 65ms/step
# Epoch 89/2000
# 16/16 - 1s - loss: 1.8027 - 1s/epoch - 65ms/step
# Epoch 90/2000
# 16/16 - 1s - loss: 1.7975 - 1s/epoch - 65ms/step
# Epoch 91/2000
# 16/16 - 1s - loss: 1.7936 - 1s/epoch - 66ms/step
# Epoch 92/2000
# 16/16 - 1s - loss: 1.7918 - 1s/epoch - 64ms/step
# Epoch 93/2000
# 16/16 - 1s - loss: 1.7869 - 1s/epoch - 65ms/step
# Epoch 94/2000
# 16/16 - 1s - loss: 1.7861 - 1s/epoch - 65ms/step
# Epoch 95/2000
# 16/16 - 1s - loss: 1.7840 - 1s/epoch - 65ms/step
# Epoch 96/2000
# 16/16 - 1s - loss: 1.7803 - 1s/epoch - 65ms/step
# Epoch 97/2000
# 16/16 - 1s - loss: 1.7772 - 1s/epoch - 65ms/step
# Epoch 98/2000
# 16/16 - 1s - loss: 1.7741 - 1s/epoch - 65ms/step
# Epoch 99/2000
# 16/16 - 1s - loss: 1.7709 - 1s/epoch - 65ms/step
# Epoch 100/2000
# 16/16 - 1s - loss: 1.7661 - 1s/epoch - 65ms/step
# Epoch 101/2000
# 16/16 - 1s - loss: 1.7667 - 1s/epoch - 65ms/step
# Epoch 102/2000
# 16/16 - 1s - loss: 1.7628 - 1s/epoch - 65ms/step
# Epoch 103/2000
# 16/16 - 1s - loss: 1.7592 - 1s/epoch - 65ms/step
# Epoch 104/2000
# 16/16 - 1s - loss: 1.7562 - 1s/epoch - 65ms/step
# Epoch 105/2000
# 16/16 - 1s - loss: 1.7550 - 1s/epoch - 66ms/step
# Epoch 106/2000
# 16/16 - 1s - loss: 1.7526 - 1s/epoch - 65ms/step
# Epoch 107/2000
# 16/16 - 1s - loss: 1.7477 - 1s/epoch - 64ms/step
# Epoch 108/2000
# 16/16 - 1s - loss: 1.7460 - 1s/epoch - 66ms/step
# Epoch 109/2000
# 16/16 - 1s - loss: 1.7418 - 1s/epoch - 66ms/step
# Epoch 110/2000
# 16/16 - 1s - loss: 1.7384 - 1s/epoch - 65ms/step
# Epoch 111/2000
# 16/16 - 1s - loss: 1.7352 - 1s/epoch - 65ms/step
# Epoch 112/2000
# 16/16 - 1s - loss: 1.7389 - 1s/epoch - 73ms/step
# Epoch 113/2000
# 16/16 - 1s - loss: 1.7321 - 1s/epoch - 65ms/step
# Epoch 114/2000
# 16/16 - 1s - loss: 1.7298 - 1s/epoch - 65ms/step
# Epoch 115/2000
# 16/16 - 1s - loss: 1.7240 - 1s/epoch - 66ms/step
# Epoch 116/2000
# 16/16 - 1s - loss: 1.7244 - 1s/epoch - 65ms/step
# Epoch 117/2000
# 16/16 - 1s - loss: 1.7205 - 1s/epoch - 66ms/step
# Epoch 118/2000
# 16/16 - 1s - loss: 1.7184 - 1s/epoch - 65ms/step
# Epoch 119/2000
# 16/16 - 1s - loss: 1.7161 - 1s/epoch - 65ms/step
# Epoch 120/2000
# 16/16 - 1s - loss: 1.7137 - 1s/epoch - 65ms/step
# Epoch 121/2000
# 16/16 - 1s - loss: 1.7112 - 1s/epoch - 65ms/step
# Epoch 122/2000
# 16/16 - 1s - loss: 1.7063 - 1s/epoch - 65ms/step
# Epoch 123/2000
# 16/16 - 1s - loss: 1.6993 - 1s/epoch - 65ms/step
# Epoch 124/2000
# 16/16 - 1s - loss: 1.6992 - 1s/epoch - 65ms/step
# Epoch 125/2000
# 16/16 - 1s - loss: 1.6963 - 1s/epoch - 65ms/step
# Epoch 126/2000
# 16/16 - 1s - loss: 1.6958 - 1s/epoch - 68ms/step
# Epoch 127/2000
# 16/16 - 1s - loss: 1.6903 - 1s/epoch - 65ms/step
# Epoch 128/2000
# 16/16 - 1s - loss: 1.6884 - 1s/epoch - 65ms/step
# Epoch 129/2000
# 16/16 - 1s - loss: 1.6876 - 1s/epoch - 65ms/step
# Epoch 130/2000
# 16/16 - 1s - loss: 1.6822 - 1s/epoch - 66ms/step
# Epoch 131/2000
# 16/16 - 1s - loss: 1.6793 - 1s/epoch - 65ms/step
# Epoch 132/2000
# 16/16 - 1s - loss: 1.6782 - 1s/epoch - 64ms/step
# Epoch 133/2000
# 16/16 - 1s - loss: 1.6707 - 1s/epoch - 65ms/step
# Epoch 134/2000
# 16/16 - 1s - loss: 1.6697 - 1s/epoch - 65ms/step
# Epoch 135/2000
# 16/16 - 1s - loss: 1.6647 - 1s/epoch - 64ms/step
# Epoch 136/2000
# 16/16 - 1s - loss: 1.6624 - 1s/epoch - 65ms/step
# Epoch 137/2000
# 16/16 - 1s - loss: 1.6602 - 1s/epoch - 65ms/step
# Epoch 138/2000
# 16/16 - 1s - loss: 1.6560 - 1s/epoch - 65ms/step
# Epoch 139/2000
# 16/16 - 1s - loss: 1.6543 - 1s/epoch - 66ms/step
# Epoch 140/2000
# 16/16 - 1s - loss: 1.6509 - 1s/epoch - 73ms/step
# Epoch 141/2000
# 16/16 - 1s - loss: 1.6477 - 1s/epoch - 65ms/step
# Epoch 142/2000
# 16/16 - 1s - loss: 1.6433 - 1s/epoch - 64ms/step
# Epoch 143/2000
# 16/16 - 1s - loss: 1.6406 - 1s/epoch - 65ms/step
# Epoch 144/2000
# 16/16 - 1s - loss: 1.6344 - 1s/epoch - 65ms/step
# Epoch 145/2000
# 16/16 - 1s - loss: 1.6326 - 1s/epoch - 65ms/step
# Epoch 146/2000
# 16/16 - 1s - loss: 1.6273 - 1s/epoch - 66ms/step
# Epoch 147/2000
# 16/16 - 1s - loss: 1.6225 - 1s/epoch - 65ms/step
# Epoch 148/2000
# 16/16 - 1s - loss: 1.6213 - 1s/epoch - 65ms/step
# Epoch 149/2000
# 16/16 - 1s - loss: 1.6176 - 1s/epoch - 65ms/step
# Epoch 150/2000
# 16/16 - 1s - loss: 1.6111 - 1s/epoch - 65ms/step
# Epoch 151/2000
# 16/16 - 1s - loss: 1.6052 - 1s/epoch - 65ms/step
# Epoch 152/2000
# 16/16 - 1s - loss: 1.6051 - 1s/epoch - 65ms/step
# Epoch 153/2000
# 16/16 - 1s - loss: 1.5981 - 1s/epoch - 68ms/step
# Epoch 154/2000
# 16/16 - 1s - loss: 1.5995 - 1s/epoch - 64ms/step
# Epoch 155/2000
# 16/16 - 1s - loss: 1.5908 - 1s/epoch - 66ms/step
# Epoch 156/2000
# 16/16 - 1s - loss: 1.5894 - 1s/epoch - 65ms/step
# Epoch 157/2000
# 16/16 - 1s - loss: 1.5817 - 1s/epoch - 64ms/step
# Epoch 158/2000
# 16/16 - 1s - loss: 1.5771 - 1s/epoch - 65ms/step
# Epoch 159/2000
# 16/16 - 1s - loss: 1.5711 - 1s/epoch - 65ms/step
# Epoch 160/2000
# 16/16 - 1s - loss: 1.5698 - 1s/epoch - 65ms/step
# Epoch 161/2000
# 16/16 - 1s - loss: 1.5625 - 1s/epoch - 65ms/step
# Epoch 162/2000
# 16/16 - 1s - loss: 1.5557 - 1s/epoch - 65ms/step
# Epoch 163/2000
# 16/16 - 1s - loss: 1.5527 - 1s/epoch - 65ms/step
# Epoch 164/2000
# 16/16 - 1s - loss: 1.5483 - 1s/epoch - 65ms/step
# Epoch 165/2000
# 16/16 - 1s - loss: 1.5406 - 1s/epoch - 65ms/step
# Epoch 166/2000
# 16/16 - 1s - loss: 1.5301 - 1s/epoch - 66ms/step
# Epoch 167/2000
# 16/16 - 1s - loss: 1.5245 - 1s/epoch - 65ms/step
# Epoch 168/2000
# 16/16 - 1s - loss: 1.5204 - 1s/epoch - 69ms/step
# Epoch 169/2000
# 16/16 - 1s - loss: 1.5174 - 1s/epoch - 72ms/step
# Epoch 170/2000
# 16/16 - 1s - loss: 1.5097 - 1s/epoch - 66ms/step
# Epoch 171/2000
# 16/16 - 1s - loss: 1.4988 - 1s/epoch - 65ms/step
# Epoch 172/2000
# 16/16 - 1s - loss: 1.4917 - 1s/epoch - 65ms/step
# Epoch 173/2000
# 16/16 - 1s - loss: 1.4853 - 1s/epoch - 65ms/step
# Epoch 174/2000
# 16/16 - 1s - loss: 1.4787 - 1s/epoch - 66ms/step
# Epoch 175/2000
# 16/16 - 1s - loss: 1.4677 - 1s/epoch - 65ms/step
# Epoch 176/2000
# 16/16 - 1s - loss: 1.4602 - 1s/epoch - 65ms/step
# Epoch 177/2000
# 16/16 - 1s - loss: 1.4562 - 1s/epoch - 65ms/step
# Epoch 178/2000
# 16/16 - 1s - loss: 1.4484 - 1s/epoch - 65ms/step
# Epoch 179/2000
# 16/16 - 1s - loss: 1.4403 - 1s/epoch - 65ms/step
# Epoch 180/2000
# 16/16 - 1s - loss: 1.4282 - 1s/epoch - 68ms/step
# Epoch 181/2000
# 16/16 - 1s - loss: 1.4165 - 1s/epoch - 65ms/step
# Epoch 182/2000
# 16/16 - 1s - loss: 1.4075 - 1s/epoch - 65ms/step
# Epoch 183/2000
# 16/16 - 1s - loss: 1.4024 - 1s/epoch - 66ms/step
# Epoch 184/2000
# 16/16 - 1s - loss: 1.3964 - 1s/epoch - 65ms/step
# Epoch 185/2000
# 16/16 - 1s - loss: 1.3818 - 1s/epoch - 65ms/step
# Epoch 186/2000
# 16/16 - 1s - loss: 1.3734 - 1s/epoch - 65ms/step
# Epoch 187/2000
# 16/16 - 1s - loss: 1.3587 - 1s/epoch - 66ms/step
# Epoch 188/2000
# 16/16 - 1s - loss: 1.3498 - 1s/epoch - 65ms/step
# Epoch 189/2000
# 16/16 - 1s - loss: 1.3392 - 1s/epoch - 69ms/step
# Epoch 190/2000
# 16/16 - 1s - loss: 1.3256 - 1s/epoch - 68ms/step
# Epoch 191/2000
# 16/16 - 1s - loss: 1.3236 - 1s/epoch - 65ms/step
# Epoch 192/2000
# 16/16 - 1s - loss: 1.3014 - 1s/epoch - 65ms/step
# Epoch 193/2000
# 16/16 - 1s - loss: 1.2879 - 1s/epoch - 65ms/step
# Epoch 194/2000
# 16/16 - 1s - loss: 1.2827 - 1s/epoch - 65ms/step
# Epoch 195/2000
# 16/16 - 1s - loss: 1.2742 - 1s/epoch - 65ms/step
# Epoch 196/2000
# 16/16 - 1s - loss: 1.2602 - 1s/epoch - 65ms/step
# Epoch 197/2000
# 16/16 - 1s - loss: 1.2475 - 1s/epoch - 74ms/step
# Epoch 198/2000
# 16/16 - 1s - loss: 1.2414 - 1s/epoch - 68ms/step
# Epoch 199/2000
# 16/16 - 1s - loss: 1.2214 - 1s/epoch - 65ms/step
# Epoch 200/2000
# 16/16 - 1s - loss: 1.2104 - 1s/epoch - 65ms/step
# Epoch 201/2000
# 16/16 - 1s - loss: 1.1970 - 1s/epoch - 66ms/step
# Epoch 202/2000
# 16/16 - 1s - loss: 1.1892 - 1s/epoch - 65ms/step
# Epoch 203/2000
# 16/16 - 1s - loss: 1.1739 - 1s/epoch - 65ms/step
# Epoch 204/2000
# 16/16 - 1s - loss: 1.1659 - 1s/epoch - 64ms/step
# Epoch 205/2000
# 16/16 - 1s - loss: 1.1547 - 1s/epoch - 65ms/step
# Epoch 206/2000
# 16/16 - 1s - loss: 1.1436 - 1s/epoch - 65ms/step
# Epoch 207/2000
# 16/16 - 1s - loss: 1.1330 - 1s/epoch - 67ms/step
# Epoch 208/2000
# 16/16 - 1s - loss: 1.1207 - 1s/epoch - 65ms/step
# Epoch 209/2000
# 16/16 - 1s - loss: 1.1035 - 1s/epoch - 64ms/step
# Epoch 210/2000
# 16/16 - 1s - loss: 1.0907 - 1s/epoch - 65ms/step
# Epoch 211/2000
# 16/16 - 1s - loss: 1.0884 - 1s/epoch - 65ms/step
# Epoch 212/2000
# 16/16 - 1s - loss: 1.0819 - 1s/epoch - 65ms/step
# Epoch 213/2000
# 16/16 - 1s - loss: 1.0603 - 1s/epoch - 65ms/step
# Epoch 214/2000
# 16/16 - 1s - loss: 1.0415 - 1s/epoch - 65ms/step
# Epoch 215/2000
# 16/16 - 1s - loss: 1.0312 - 1s/epoch - 66ms/step
# Epoch 216/2000
# 16/16 - 1s - loss: 1.0171 - 1s/epoch - 68ms/step
# Epoch 217/2000
# 16/16 - 1s - loss: 1.0102 - 1s/epoch - 65ms/step
# Epoch 218/2000
# 16/16 - 1s - loss: 0.9992 - 1s/epoch - 65ms/step
# Epoch 219/2000
# 16/16 - 1s - loss: 0.9887 - 1s/epoch - 64ms/step
# Epoch 220/2000
# 16/16 - 1s - loss: 0.9843 - 1s/epoch - 65ms/step
# Epoch 221/2000
# 16/16 - 1s - loss: 0.9679 - 1s/epoch - 65ms/step
# Epoch 222/2000
# 16/16 - 1s - loss: 0.9548 - 1s/epoch - 65ms/step
# Epoch 223/2000
# 16/16 - 1s - loss: 0.9505 - 1s/epoch - 65ms/step
# Epoch 224/2000
# 16/16 - 1s - loss: 0.9350 - 1s/epoch - 65ms/step
# Epoch 225/2000
# 16/16 - 1s - loss: 0.9318 - 1s/epoch - 67ms/step
# Epoch 226/2000
# 16/16 - 1s - loss: 0.9178 - 1s/epoch - 77ms/step
# Epoch 227/2000
# 16/16 - 1s - loss: 0.9004 - 1s/epoch - 65ms/step
# Epoch 228/2000
# 16/16 - 1s - loss: 0.8959 - 1s/epoch - 65ms/step
# Epoch 229/2000
# 16/16 - 1s - loss: 0.8820 - 1s/epoch - 65ms/step
# Epoch 230/2000
# 16/16 - 1s - loss: 0.8728 - 1s/epoch - 65ms/step
# Epoch 231/2000
# 16/16 - 1s - loss: 0.8655 - 1s/epoch - 64ms/step
# Epoch 232/2000
# 16/16 - 1s - loss: 0.8521 - 1s/epoch - 64ms/step
# Epoch 233/2000
# 16/16 - 1s - loss: 0.8393 - 1s/epoch - 65ms/step
# Epoch 234/2000
# 16/16 - 1s - loss: 0.8279 - 1s/epoch - 67ms/step
# Epoch 235/2000
# 16/16 - 1s - loss: 0.8239 - 1s/epoch - 65ms/step
# Epoch 236/2000
# 16/16 - 1s - loss: 0.8121 - 1s/epoch - 65ms/step
# Epoch 237/2000
# 16/16 - 1s - loss: 0.7980 - 1s/epoch - 65ms/step
# Epoch 238/2000
# 16/16 - 1s - loss: 0.7972 - 1s/epoch - 65ms/step
# Epoch 239/2000
# 16/16 - 1s - loss: 0.7907 - 1s/epoch - 65ms/step
# Epoch 240/2000
# 16/16 - 1s - loss: 0.7843 - 1s/epoch - 65ms/step
# Epoch 241/2000
# 16/16 - 1s - loss: 0.7744 - 1s/epoch - 65ms/step
# Epoch 242/2000
# 16/16 - 1s - loss: 0.7615 - 1s/epoch - 65ms/step
# Epoch 243/2000
# 16/16 - 1s - loss: 0.7451 - 1s/epoch - 67ms/step
# Epoch 244/2000
# 16/16 - 1s - loss: 0.7386 - 1s/epoch - 65ms/step
# Epoch 245/2000
# 16/16 - 1s - loss: 0.7365 - 1s/epoch - 65ms/step
# Epoch 246/2000
# 16/16 - 1s - loss: 0.7316 - 1s/epoch - 65ms/step
# Epoch 247/2000
# 16/16 - 1s - loss: 0.7262 - 1s/epoch - 65ms/step
# Epoch 248/2000
# 16/16 - 1s - loss: 0.7149 - 1s/epoch - 65ms/step
# Epoch 249/2000
# 16/16 - 1s - loss: 0.7070 - 1s/epoch - 65ms/step
# Epoch 250/2000
# 16/16 - 1s - loss: 0.6979 - 1s/epoch - 66ms/step
# Epoch 251/2000
# 16/16 - 1s - loss: 0.6824 - 1s/epoch - 65ms/step
# Epoch 252/2000
# 16/16 - 1s - loss: 0.6731 - 1s/epoch - 65ms/step
# Epoch 253/2000
# 16/16 - 1s - loss: 0.6690 - 1s/epoch - 64ms/step
# Epoch 254/2000
# 16/16 - 1s - loss: 0.6620 - 1s/epoch - 66ms/step
# Epoch 255/2000
# 16/16 - 1s - loss: 0.6553 - 1s/epoch - 73ms/step
# Epoch 256/2000
# 16/16 - 1s - loss: 0.6518 - 1s/epoch - 65ms/step
# Epoch 257/2000
# 16/16 - 1s - loss: 0.6444 - 1s/epoch - 65ms/step
# Epoch 258/2000
# 16/16 - 1s - loss: 0.6345 - 1s/epoch - 66ms/step
# Epoch 259/2000
# 16/16 - 1s - loss: 0.6281 - 1s/epoch - 65ms/step
# Epoch 260/2000
# 16/16 - 1s - loss: 0.6264 - 1s/epoch - 65ms/step
# Epoch 261/2000
# 16/16 - 1s - loss: 0.6155 - 1s/epoch - 65ms/step
# Epoch 262/2000
# 16/16 - 1s - loss: 0.6075 - 1s/epoch - 65ms/step
# Epoch 263/2000
# 16/16 - 1s - loss: 0.6004 - 1s/epoch - 64ms/step
# Epoch 264/2000
# 16/16 - 1s - loss: 0.5952 - 1s/epoch - 65ms/step
# Epoch 265/2000
# 16/16 - 1s - loss: 0.5895 - 1s/epoch - 65ms/step
# Epoch 266/2000
# 16/16 - 1s - loss: 0.5864 - 1s/epoch - 64ms/step
# Epoch 267/2000
# 16/16 - 1s - loss: 0.5776 - 1s/epoch - 65ms/step
# Epoch 268/2000
# 16/16 - 1s - loss: 0.5745 - 1s/epoch - 64ms/step
# Epoch 269/2000
# 16/16 - 1s - loss: 0.5659 - 1s/epoch - 65ms/step
# Epoch 270/2000
# 16/16 - 1s - loss: 0.5602 - 1s/epoch - 65ms/step
# Epoch 271/2000
# 16/16 - 1s - loss: 0.5508 - 1s/epoch - 65ms/step
# Epoch 272/2000
# 16/16 - 1s - loss: 0.5437 - 1s/epoch - 64ms/step
# Epoch 273/2000
# 16/16 - 1s - loss: 0.5388 - 1s/epoch - 65ms/step
# Epoch 274/2000
# 16/16 - 1s - loss: 0.5325 - 1s/epoch - 65ms/step
# Epoch 275/2000
# 16/16 - 1s - loss: 0.5283 - 1s/epoch - 66ms/step
# Epoch 276/2000
# 16/16 - 1s - loss: 0.5241 - 1s/epoch - 65ms/step
# Epoch 277/2000
# 16/16 - 1s - loss: 0.5187 - 1s/epoch - 65ms/step
# Epoch 278/2000
# 16/16 - 1s - loss: 0.5173 - 1s/epoch - 66ms/step
# Epoch 279/2000
# 16/16 - 1s - loss: 0.5104 - 1s/epoch - 65ms/step
# Epoch 280/2000
# 16/16 - 1s - loss: 0.5072 - 1s/epoch - 65ms/step
# Epoch 281/2000
# 16/16 - 1s - loss: 0.5003 - 1s/epoch - 64ms/step
# Epoch 282/2000
# 16/16 - 1s - loss: 0.4916 - 1s/epoch - 65ms/step
# Epoch 283/2000
# 16/16 - 1s - loss: 0.4896 - 1s/epoch - 72ms/step
# Epoch 284/2000
# 16/16 - 1s - loss: 0.4897 - 1s/epoch - 65ms/step
# Epoch 285/2000
# 16/16 - 1s - loss: 0.4871 - 1s/epoch - 67ms/step
# Epoch 286/2000
# 16/16 - 1s - loss: 0.4795 - 1s/epoch - 65ms/step
# Epoch 287/2000
# 16/16 - 1s - loss: 0.4734 - 1s/epoch - 64ms/step
# Epoch 288/2000
# 16/16 - 1s - loss: 0.4681 - 1s/epoch - 65ms/step
# Epoch 289/2000
# 16/16 - 1s - loss: 0.4629 - 1s/epoch - 65ms/step
# Epoch 290/2000
# 16/16 - 1s - loss: 0.4567 - 1s/epoch - 64ms/step
# Epoch 291/2000
# 16/16 - 1s - loss: 0.4548 - 1s/epoch - 65ms/step
# Epoch 292/2000
# 16/16 - 1s - loss: 0.4495 - 1s/epoch - 65ms/step
# Epoch 293/2000
# 16/16 - 1s - loss: 0.4473 - 1s/epoch - 65ms/step
# Epoch 294/2000
# 16/16 - 1s - loss: 0.4472 - 1s/epoch - 65ms/step
# Epoch 295/2000
# 16/16 - 1s - loss: 0.4410 - 1s/epoch - 65ms/step
# Epoch 296/2000
# 16/16 - 1s - loss: 0.4367 - 1s/epoch - 65ms/step
# Epoch 297/2000
# 16/16 - 1s - loss: 0.4328 - 1s/epoch - 65ms/step
# Epoch 298/2000
# 16/16 - 1s - loss: 0.4296 - 1s/epoch - 67ms/step
# Epoch 299/2000
# 16/16 - 1s - loss: 0.4273 - 1s/epoch - 65ms/step
# Epoch 300/2000
# 16/16 - 1s - loss: 0.4235 - 1s/epoch - 65ms/step
# Epoch 301/2000
# 16/16 - 1s - loss: 0.4165 - 1s/epoch - 65ms/step
# Epoch 302/2000
# 16/16 - 1s - loss: 0.4159 - 1s/epoch - 65ms/step
# Epoch 303/2000
# 16/16 - 1s - loss: 0.4114 - 1s/epoch - 65ms/step
# Epoch 304/2000
# 16/16 - 1s - loss: 0.4088 - 1s/epoch - 65ms/step
# Epoch 305/2000
# 16/16 - 1s - loss: 0.4037 - 1s/epoch - 65ms/step
# Epoch 306/2000
# 16/16 - 1s - loss: 0.3999 - 1s/epoch - 64ms/step
# Epoch 307/2000
# 16/16 - 1s - loss: 0.3975 - 1s/epoch - 65ms/step
# Epoch 308/2000
# 16/16 - 1s - loss: 0.3928 - 1s/epoch - 64ms/step
# Epoch 309/2000
# 16/16 - 1s - loss: 0.3900 - 1s/epoch - 65ms/step
# Epoch 310/2000
# 16/16 - 1s - loss: 0.3877 - 1s/epoch - 74ms/step
# Epoch 311/2000
# 16/16 - 1s - loss: 0.3825 - 1s/epoch - 65ms/step
# Epoch 312/2000
# 16/16 - 1s - loss: 0.3815 - 1s/epoch - 65ms/step
# Epoch 313/2000
# 16/16 - 1s - loss: 0.3793 - 1s/epoch - 65ms/step
# Epoch 314/2000
# 16/16 - 1s - loss: 0.3775 - 1s/epoch - 65ms/step
# Epoch 315/2000
# 16/16 - 1s - loss: 0.3738 - 1s/epoch - 65ms/step
# Epoch 316/2000
# 16/16 - 1s - loss: 0.3740 - 1s/epoch - 65ms/step
# Epoch 317/2000
# 16/16 - 1s - loss: 0.3740 - 1s/epoch - 64ms/step
# Epoch 318/2000
# 16/16 - 1s - loss: 0.3710 - 1s/epoch - 64ms/step
# Epoch 319/2000
# 16/16 - 1s - loss: 0.3681 - 1s/epoch - 65ms/step
# Epoch 320/2000
# 16/16 - 1s - loss: 0.3649 - 1s/epoch - 64ms/step
# Epoch 321/2000
# 16/16 - 1s - loss: 0.3622 - 1s/epoch - 65ms/step
# Epoch 322/2000
# 16/16 - 1s - loss: 0.3598 - 1s/epoch - 65ms/step
# Epoch 323/2000
# 16/16 - 1s - loss: 0.3562 - 1s/epoch - 65ms/step
# Epoch 324/2000
# 16/16 - 1s - loss: 0.3538 - 1s/epoch - 64ms/step
# Epoch 325/2000
# 16/16 - 1s - loss: 0.3541 - 1s/epoch - 67ms/step
# Epoch 326/2000
# 16/16 - 1s - loss: 0.3520 - 1s/epoch - 65ms/step
# Epoch 327/2000
# 16/16 - 1s - loss: 0.3491 - 1s/epoch - 65ms/step
# Epoch 328/2000
# 16/16 - 1s - loss: 0.3447 - 1s/epoch - 64ms/step
# Epoch 329/2000
# 16/16 - 1s - loss: 0.3405 - 1s/epoch - 65ms/step
# Epoch 330/2000
# 16/16 - 1s - loss: 0.3379 - 1s/epoch - 65ms/step
# Epoch 331/2000
# 16/16 - 1s - loss: 0.3366 - 1s/epoch - 65ms/step
# Epoch 332/2000
# 16/16 - 1s - loss: 0.3351 - 1s/epoch - 65ms/step
# Epoch 333/2000
# 16/16 - 1s - loss: 0.3332 - 1s/epoch - 66ms/step
# Epoch 334/2000
# 16/16 - 1s - loss: 0.3307 - 1s/epoch - 64ms/step
# Epoch 335/2000
# 16/16 - 1s - loss: 0.3270 - 1s/epoch - 64ms/step
# Epoch 336/2000
# 16/16 - 1s - loss: 0.3222 - 1s/epoch - 65ms/step
# Epoch 337/2000
# 16/16 - 1s - loss: 0.3204 - 1s/epoch - 65ms/step
# Epoch 338/2000
# 16/16 - 1s - loss: 0.3190 - 1s/epoch - 65ms/step
# Epoch 339/2000
# 16/16 - 1s - loss: 0.3149 - 1s/epoch - 75ms/step
# Epoch 340/2000
# 16/16 - 1s - loss: 0.3156 - 1s/epoch - 68ms/step
# Epoch 341/2000
# 16/16 - 1s - loss: 0.3138 - 1s/epoch - 66ms/step
# Epoch 342/2000
# 16/16 - 1s - loss: 0.3143 - 1s/epoch - 66ms/step
# Epoch 343/2000
# 16/16 - 1s - loss: 0.3115 - 1s/epoch - 65ms/step
# Epoch 344/2000
# 16/16 - 1s - loss: 0.3107 - 1s/epoch - 65ms/step
# Epoch 345/2000
# 16/16 - 1s - loss: 0.3093 - 1s/epoch - 65ms/step
# Epoch 346/2000
# 16/16 - 1s - loss: 0.3067 - 1s/epoch - 65ms/step
# Epoch 347/2000
# 16/16 - 1s - loss: 0.3064 - 1s/epoch - 64ms/step
# Epoch 348/2000
# 16/16 - 1s - loss: 0.3015 - 1s/epoch - 65ms/step
# Epoch 349/2000
# 16/16 - 1s - loss: 0.3002 - 1s/epoch - 65ms/step
# Epoch 350/2000
# 16/16 - 1s - loss: 0.2997 - 1s/epoch - 64ms/step
# Epoch 351/2000
# 16/16 - 1s - loss: 0.2979 - 1s/epoch - 65ms/step
# Epoch 352/2000
# 16/16 - 1s - loss: 0.2950 - 1s/epoch - 65ms/step
# Epoch 353/2000
# 16/16 - 1s - loss: 0.2933 - 1s/epoch - 65ms/step
# Epoch 354/2000
# 16/16 - 1s - loss: 0.2920 - 1s/epoch - 65ms/step
# Epoch 355/2000
# 16/16 - 1s - loss: 0.2908 - 1s/epoch - 65ms/step
# Epoch 356/2000
# 16/16 - 1s - loss: 0.2892 - 1s/epoch - 65ms/step
# Epoch 357/2000
# 16/16 - 1s - loss: 0.2888 - 1s/epoch - 64ms/step
# Epoch 358/2000
# 16/16 - 1s - loss: 0.2856 - 1s/epoch - 65ms/step
# Epoch 359/2000
# 16/16 - 1s - loss: 0.2854 - 1s/epoch - 65ms/step
# Epoch 360/2000
# 16/16 - 1s - loss: 0.2831 - 1s/epoch - 68ms/step
# Epoch 361/2000
# 16/16 - 1s - loss: 0.2792 - 1s/epoch - 65ms/step
# Epoch 362/2000
# 16/16 - 1s - loss: 0.2786 - 1s/epoch - 65ms/step
# Epoch 363/2000
# 16/16 - 1s - loss: 0.2767 - 1s/epoch - 64ms/step
# Epoch 364/2000
# 16/16 - 1s - loss: 0.2754 - 1s/epoch - 65ms/step
# Epoch 365/2000
# 16/16 - 1s - loss: 0.2750 - 1s/epoch - 65ms/step
# Epoch 366/2000
# 16/16 - 1s - loss: 0.2724 - 1s/epoch - 65ms/step
# Epoch 367/2000
# 16/16 - 1s - loss: 0.2714 - 1s/epoch - 73ms/step
# Epoch 368/2000
# 16/16 - 1s - loss: 0.2734 - 1s/epoch - 72ms/step
# Epoch 369/2000
# 16/16 - 1s - loss: 0.2722 - 1s/epoch - 64ms/step
# Epoch 370/2000
# 16/16 - 1s - loss: 0.2716 - 1s/epoch - 65ms/step
# Epoch 371/2000
# 16/16 - 1s - loss: 0.2707 - 1s/epoch - 66ms/step
# Epoch 372/2000
# 16/16 - 1s - loss: 0.2694 - 1s/epoch - 65ms/step
# Epoch 373/2000
# 16/16 - 1s - loss: 0.2692 - 1s/epoch - 65ms/step
# Epoch 374/2000
# 16/16 - 1s - loss: 0.2671 - 1s/epoch - 65ms/step
# Epoch 375/2000
# 16/16 - 1s - loss: 0.2656 - 1s/epoch - 65ms/step
# Epoch 376/2000
# 16/16 - 1s - loss: 0.2681 - 1s/epoch - 64ms/step
# Epoch 377/2000
# 16/16 - 1s - loss: 0.2670 - 1s/epoch - 66ms/step
# Epoch 378/2000
# 16/16 - 1s - loss: 0.2643 - 1s/epoch - 65ms/step
# Epoch 379/2000
# 16/16 - 1s - loss: 0.2597 - 1s/epoch - 65ms/step
# Epoch 380/2000
# 16/16 - 1s - loss: 0.2601 - 1s/epoch - 64ms/step
# Epoch 381/2000
# 16/16 - 1s - loss: 0.2562 - 1s/epoch - 64ms/step
# Epoch 382/2000
# 16/16 - 1s - loss: 0.2545 - 1s/epoch - 64ms/step
# Epoch 383/2000
# 16/16 - 1s - loss: 0.2514 - 1s/epoch - 64ms/step
# Epoch 384/2000
# 16/16 - 1s - loss: 0.2499 - 1s/epoch - 65ms/step
# Epoch 385/2000
# 16/16 - 1s - loss: 0.2482 - 1s/epoch - 65ms/step
# Epoch 386/2000
# 16/16 - 1s - loss: 0.2459 - 1s/epoch - 65ms/step
# Epoch 387/2000
# 16/16 - 1s - loss: 0.2444 - 1s/epoch - 65ms/step
# Epoch 388/2000
# 16/16 - 1s - loss: 0.2422 - 1s/epoch - 65ms/step
# Epoch 389/2000
# 16/16 - 1s - loss: 0.2407 - 1s/epoch - 65ms/step
# Epoch 390/2000
# 16/16 - 1s - loss: 0.2398 - 1s/epoch - 65ms/step
# Epoch 391/2000
# 16/16 - 1s - loss: 0.2382 - 1s/epoch - 65ms/step
# Epoch 392/2000
# 16/16 - 1s - loss: 0.2383 - 1s/epoch - 65ms/step
# Epoch 393/2000
# 16/16 - 1s - loss: 0.2378 - 1s/epoch - 65ms/step
# Epoch 394/2000
# 16/16 - 1s - loss: 0.2369 - 1s/epoch - 64ms/step
# Epoch 395/2000
# 16/16 - 1s - loss: 0.2374 - 1s/epoch - 65ms/step
# Epoch 396/2000
# 16/16 - 1s - loss: 0.2358 - 1s/epoch - 76ms/step
# Epoch 397/2000
# 16/16 - 1s - loss: 0.2356 - 1s/epoch - 73ms/step
# Epoch 398/2000
# 16/16 - 1s - loss: 0.2363 - 1s/epoch - 65ms/step
# Epoch 399/2000
# 16/16 - 1s - loss: 0.2333 - 1s/epoch - 65ms/step
# Epoch 400/2000
# 16/16 - 1s - loss: 0.2346 - 1s/epoch - 65ms/step
# Epoch 401/2000
# 16/16 - 1s - loss: 0.2323 - 1s/epoch - 65ms/step
# Epoch 402/2000
# 16/16 - 1s - loss: 0.2314 - 1s/epoch - 65ms/step
# Epoch 403/2000
# 16/16 - 1s - loss: 0.2302 - 1s/epoch - 65ms/step
# Epoch 404/2000
# 16/16 - 1s - loss: 0.2320 - 1s/epoch - 65ms/step
# Epoch 405/2000
# 16/16 - 1s - loss: 0.2303 - 1s/epoch - 69ms/step
# Epoch 406/2000
# 16/16 - 1s - loss: 0.2305 - 1s/epoch - 65ms/step
# Epoch 407/2000
# 16/16 - 1s - loss: 0.2293 - 1s/epoch - 65ms/step
# Epoch 408/2000
# 16/16 - 1s - loss: 0.2259 - 1s/epoch - 67ms/step
# Epoch 409/2000
# 16/16 - 1s - loss: 0.2265 - 1s/epoch - 65ms/step
# Epoch 410/2000
# 16/16 - 1s - loss: 0.2272 - 1s/epoch - 65ms/step
# Epoch 411/2000
# 16/16 - 1s - loss: 0.2284 - 1s/epoch - 65ms/step
# Epoch 412/2000
# 16/16 - 1s - loss: 0.2292 - 1s/epoch - 65ms/step
# Epoch 413/2000
# 16/16 - 1s - loss: 0.2283 - 1s/epoch - 65ms/step
# Epoch 414/2000
# 16/16 - 1s - loss: 0.2235 - 1s/epoch - 65ms/step
# Epoch 415/2000
# 16/16 - 1s - loss: 0.2215 - 1s/epoch - 65ms/step
# Epoch 416/2000
# 16/16 - 1s - loss: 0.2178 - 1s/epoch - 65ms/step
# Epoch 417/2000
# 16/16 - 1s - loss: 0.2143 - 1s/epoch - 64ms/step
# Epoch 418/2000
# 16/16 - 1s - loss: 0.2124 - 1s/epoch - 65ms/step
# Epoch 419/2000
# 16/16 - 1s - loss: 0.2100 - 1s/epoch - 65ms/step
# Epoch 420/2000
# 16/16 - 1s - loss: 0.2094 - 1s/epoch - 65ms/step
# Epoch 421/2000
# 16/16 - 1s - loss: 0.2088 - 1s/epoch - 64ms/step
# Epoch 422/2000
# 16/16 - 1s - loss: 0.2068 - 1s/epoch - 65ms/step
# Epoch 423/2000
# 16/16 - 1s - loss: 0.2037 - 1s/epoch - 67ms/step
# Epoch 424/2000
# 16/16 - 1s - loss: 0.2018 - 1s/epoch - 73ms/step
# Epoch 425/2000
# 16/16 - 1s - loss: 0.2031 - 1s/epoch - 65ms/step
# Epoch 426/2000
# 16/16 - 1s - loss: 0.2010 - 1s/epoch - 64ms/step
# Epoch 427/2000
# 16/16 - 1s - loss: 0.1998 - 1s/epoch - 65ms/step
# Epoch 428/2000
# 16/16 - 1s - loss: 0.1999 - 1s/epoch - 65ms/step
# Epoch 429/2000
# 16/16 - 1s - loss: 0.1986 - 1s/epoch - 65ms/step
# Epoch 430/2000
# 16/16 - 1s - loss: 0.1982 - 1s/epoch - 64ms/step
# Epoch 431/2000
# 16/16 - 1s - loss: 0.2001 - 1s/epoch - 65ms/step
# Epoch 432/2000
# 16/16 - 1s - loss: 0.1992 - 1s/epoch - 65ms/step
# Epoch 433/2000
# 16/16 - 1s - loss: 0.1992 - 1s/epoch - 65ms/step
# Epoch 434/2000
# 16/16 - 1s - loss: 0.2002 - 1s/epoch - 65ms/step
# Epoch 435/2000
# 16/16 - 1s - loss: 0.1997 - 1s/epoch - 67ms/step
# Epoch 436/2000
# 16/16 - 1s - loss: 0.2006 - 1s/epoch - 65ms/step
# Epoch 437/2000
# 16/16 - 1s - loss: 0.2008 - 1s/epoch - 64ms/step
# Epoch 438/2000
# 16/16 - 1s - loss: 0.2023 - 1s/epoch - 65ms/step
# Epoch 439/2000
# 16/16 - 1s - loss: 0.2048 - 1s/epoch - 65ms/step
# Epoch 440/2000
# 16/16 - 1s - loss: 0.2042 - 1s/epoch - 66ms/step
# Epoch 441/2000
# 16/16 - 1s - loss: 0.2040 - 1s/epoch - 65ms/step
# Epoch 442/2000
# 16/16 - 1s - loss: 0.2058 - 1s/epoch - 65ms/step
# Epoch 443/2000
# 16/16 - 1s - loss: 0.2041 - 1s/epoch - 65ms/step
# Epoch 444/2000
# 16/16 - 1s - loss: 0.2045 - 1s/epoch - 65ms/step
# Epoch 445/2000
# 16/16 - 1s - loss: 0.2021 - 1s/epoch - 65ms/step
# Epoch 446/2000
# 16/16 - 1s - loss: 0.2013 - 1s/epoch - 65ms/step
# Epoch 447/2000
# 16/16 - 1s - loss: 0.1970 - 1s/epoch - 65ms/step
# Epoch 448/2000
# 16/16 - 1s - loss: 0.1978 - 1s/epoch - 66ms/step
# Epoch 449/2000
# 16/16 - 1s - loss: 0.1953 - 1s/epoch - 69ms/step
# Epoch 450/2000
# 16/16 - 1s - loss: 0.1912 - 1s/epoch - 65ms/step
# Epoch 451/2000
# 16/16 - 1s - loss: 0.1876 - 1s/epoch - 66ms/step
# Epoch 452/2000
# 16/16 - 1s - loss: 0.1866 - 1s/epoch - 73ms/step
# Epoch 453/2000
# 16/16 - 1s - loss: 0.1839 - 1s/epoch - 64ms/step
# Epoch 454/2000
# 16/16 - 1s - loss: 0.1829 - 1s/epoch - 65ms/step
# Epoch 455/2000
# 16/16 - 1s - loss: 0.1812 - 1s/epoch - 64ms/step
# Epoch 456/2000
# 16/16 - 1s - loss: 0.1792 - 1s/epoch - 64ms/step
# Epoch 457/2000
# 16/16 - 1s - loss: 0.1756 - 1s/epoch - 65ms/step
# Epoch 458/2000
# 16/16 - 1s - loss: 0.1728 - 1s/epoch - 67ms/step
# Epoch 459/2000
# 16/16 - 1s - loss: 0.1730 - 1s/epoch - 65ms/step
# Epoch 460/2000
# 16/16 - 1s - loss: 0.1730 - 1s/epoch - 65ms/step
# Epoch 461/2000
# 16/16 - 1s - loss: 0.1715 - 1s/epoch - 64ms/step
# Epoch 462/2000
# 16/16 - 1s - loss: 0.1701 - 1s/epoch - 65ms/step
# Epoch 463/2000
# 16/16 - 1s - loss: 0.1687 - 1s/epoch - 67ms/step
# Epoch 464/2000
# 16/16 - 1s - loss: 0.1693 - 1s/epoch - 65ms/step
# Epoch 465/2000
# 16/16 - 1s - loss: 0.1687 - 1s/epoch - 65ms/step
# Epoch 466/2000
# 16/16 - 1s - loss: 0.1679 - 1s/epoch - 65ms/step
# Epoch 467/2000
# 16/16 - 1s - loss: 0.1665 - 1s/epoch - 66ms/step
# Epoch 468/2000
# 16/16 - 1s - loss: 0.1671 - 1s/epoch - 65ms/step
# Epoch 469/2000
# 16/16 - 1s - loss: 0.1674 - 1s/epoch - 64ms/step
# Epoch 470/2000
# 16/16 - 1s - loss: 0.1689 - 1s/epoch - 65ms/step
# Epoch 471/2000
# 16/16 - 1s - loss: 0.1710 - 1s/epoch - 65ms/step
# Epoch 472/2000
# 16/16 - 1s - loss: 0.1720 - 1s/epoch - 64ms/step
# Epoch 473/2000
# 16/16 - 1s - loss: 0.1759 - 1s/epoch - 65ms/step
# Epoch 474/2000
# 16/16 - 1s - loss: 0.1813 - 1s/epoch - 65ms/step
# Epoch 475/2000
# 16/16 - 1s - loss: 0.1860 - 1s/epoch - 65ms/step
# Epoch 476/2000
# 16/16 - 1s - loss: 0.1895 - 1s/epoch - 64ms/step
# Epoch 477/2000
# 16/16 - 1s - loss: 0.1965 - 1s/epoch - 65ms/step
# Epoch 478/2000
# 16/16 - 1s - loss: 0.2001 - 1s/epoch - 68ms/step
# Epoch 479/2000
# 16/16 - 1s - loss: 0.2024 - 1s/epoch - 65ms/step
# Epoch 480/2000
# 16/16 - 1s - loss: 0.2021 - 1s/epoch - 73ms/step
# Epoch 481/2000
# 16/16 - 1s - loss: 0.1993 - 1s/epoch - 65ms/step
# Epoch 482/2000
# 16/16 - 1s - loss: 0.1930 - 1s/epoch - 65ms/step
# Epoch 483/2000
# 16/16 - 1s - loss: 0.1884 - 1s/epoch - 65ms/step
# Epoch 484/2000
# 16/16 - 1s - loss: 0.1822 - 1s/epoch - 65ms/step
# Epoch 485/2000
# 16/16 - 1s - loss: 0.1762 - 1s/epoch - 65ms/step
# Epoch 486/2000
# 16/16 - 1s - loss: 0.1715 - 1s/epoch - 65ms/step
# Epoch 487/2000
# 16/16 - 1s - loss: 0.1658 - 1s/epoch - 65ms/step
# Epoch 488/2000
# 16/16 - 1s - loss: 0.1642 - 1s/epoch - 64ms/step
# Epoch 489/2000
# 16/16 - 1s - loss: 0.1599 - 1s/epoch - 65ms/step
# Epoch 490/2000
# 16/16 - 1s - loss: 0.1578 - 1s/epoch - 67ms/step
# Epoch 491/2000
# 16/16 - 1s - loss: 0.1557 - 1s/epoch - 64ms/step
# Epoch 492/2000
# 16/16 - 1s - loss: 0.1528 - 1s/epoch - 65ms/step
# Epoch 493/2000
# 16/16 - 1s - loss: 0.1521 - 1s/epoch - 65ms/step
# Epoch 494/2000
# 16/16 - 1s - loss: 0.1510 - 1s/epoch - 65ms/step
# Epoch 495/2000
# 16/16 - 1s - loss: 0.1504 - 1s/epoch - 64ms/step
# Epoch 496/2000
# 16/16 - 1s - loss: 0.1489 - 1s/epoch - 65ms/step
# Epoch 497/2000
# 16/16 - 1s - loss: 0.1469 - 1s/epoch - 65ms/step
# Epoch 498/2000
# 16/16 - 1s - loss: 0.1471 - 1s/epoch - 65ms/step
# Epoch 499/2000
# 16/16 - 1s - loss: 0.1456 - 1s/epoch - 65ms/step
# Epoch 500/2000
# 16/16 - 1s - loss: 0.1450 - 1s/epoch - 64ms/step
# Epoch 501/2000
# 16/16 - 1s - loss: 0.1441 - 1s/epoch - 65ms/step
# Epoch 502/2000
# 16/16 - 1s - loss: 0.1450 - 1s/epoch - 65ms/step
# Epoch 503/2000
# 16/16 - 1s - loss: 0.1448 - 1s/epoch - 65ms/step
# Epoch 504/2000
# 16/16 - 1s - loss: 0.1454 - 1s/epoch - 65ms/step
# Epoch 505/2000
# 16/16 - 1s - loss: 0.1447 - 1s/epoch - 65ms/step
# Epoch 506/2000
# 16/16 - 1s - loss: 0.1444 - 1s/epoch - 66ms/step
# Epoch 507/2000
# 16/16 - 1s - loss: 0.1433 - 1s/epoch - 64ms/step
# Epoch 508/2000
# 16/16 - 1s - loss: 0.1422 - 1s/epoch - 72ms/step
# Epoch 509/2000
# 16/16 - 1s - loss: 0.1436 - 1s/epoch - 65ms/step
# Epoch 510/2000
# 16/16 - 1s - loss: 0.1435 - 1s/epoch - 65ms/step
# Epoch 511/2000
# 16/16 - 1s - loss: 0.1444 - 1s/epoch - 65ms/step
# Epoch 512/2000
# 16/16 - 1s - loss: 0.1437 - 1s/epoch - 65ms/step
# Epoch 513/2000
# 16/16 - 1s - loss: 0.1444 - 1s/epoch - 65ms/step
# Epoch 514/2000
# 16/16 - 1s - loss: 0.1439 - 1s/epoch - 65ms/step
# Epoch 515/2000
# 16/16 - 1s - loss: 0.1455 - 1s/epoch - 64ms/step
# Epoch 516/2000
# 16/16 - 1s - loss: 0.1492 - 1s/epoch - 65ms/step
# Epoch 517/2000
# 16/16 - 1s - loss: 0.1524 - 1s/epoch - 68ms/step
# Epoch 518/2000
# 16/16 - 1s - loss: 0.1571 - 1s/epoch - 65ms/step
# Epoch 519/2000
# 16/16 - 1s - loss: 0.1630 - 1s/epoch - 65ms/step
# Epoch 520/2000
# 16/16 - 1s - loss: 0.1675 - 1s/epoch - 65ms/step
# Epoch 521/2000
# 16/16 - 1s - loss: 0.1793 - 1s/epoch - 65ms/step
# Epoch 522/2000
# 16/16 - 1s - loss: 0.1879 - 1s/epoch - 64ms/step
# Epoch 523/2000
# 16/16 - 1s - loss: 0.1979 - 1s/epoch - 64ms/step
# Epoch 524/2000
# 16/16 - 1s - loss: 0.1981 - 1s/epoch - 64ms/step
# Epoch 525/2000
# 16/16 - 1s - loss: 0.1940 - 1s/epoch - 64ms/step
# Epoch 526/2000
# 16/16 - 1s - loss: 0.1861 - 1s/epoch - 65ms/step
# Epoch 527/2000
# 16/16 - 1s - loss: 0.1789 - 1s/epoch - 64ms/step
# Epoch 528/2000
# 16/16 - 1s - loss: 0.1682 - 1s/epoch - 65ms/step
# Epoch 529/2000
# 16/16 - 1s - loss: 0.1583 - 1s/epoch - 65ms/step
# Epoch 530/2000
# 16/16 - 1s - loss: 0.1518 - 1s/epoch - 67ms/step
# Epoch 531/2000
# 16/16 - 1s - loss: 0.1447 - 1s/epoch - 64ms/step
# Epoch 532/2000
# 16/16 - 1s - loss: 0.1416 - 1s/epoch - 64ms/step
# Epoch 533/2000
# 16/16 - 1s - loss: 0.1381 - 1s/epoch - 65ms/step
# Epoch 534/2000
# 16/16 - 1s - loss: 0.1349 - 1s/epoch - 65ms/step
# Epoch 535/2000
# 16/16 - 1s - loss: 0.1337 - 1s/epoch - 64ms/step
# Epoch 536/2000
# 16/16 - 1s - loss: 0.1320 - 1s/epoch - 65ms/step
# Epoch 537/2000
# 16/16 - 1s - loss: 0.1296 - 1s/epoch - 75ms/step
# Epoch 538/2000
# 16/16 - 1s - loss: 0.1288 - 1s/epoch - 65ms/step
# Epoch 539/2000
# 16/16 - 1s - loss: 0.1280 - 1s/epoch - 67ms/step
# Epoch 540/2000
# 16/16 - 1s - loss: 0.1273 - 1s/epoch - 65ms/step
# Epoch 541/2000
# 16/16 - 1s - loss: 0.1260 - 1s/epoch - 65ms/step
# Epoch 542/2000
# 16/16 - 1s - loss: 0.1252 - 1s/epoch - 64ms/step
# Epoch 543/2000
# 16/16 - 1s - loss: 0.1252 - 1s/epoch - 64ms/step
# Epoch 544/2000
# 16/16 - 1s - loss: 0.1243 - 1s/epoch - 65ms/step
# Epoch 545/2000
# 16/16 - 1s - loss: 0.1236 - 1s/epoch - 65ms/step
# Epoch 546/2000
# 16/16 - 1s - loss: 0.1227 - 1s/epoch - 68ms/step
# Epoch 547/2000
# 16/16 - 1s - loss: 0.1227 - 1s/epoch - 64ms/step
# Epoch 548/2000
# 16/16 - 1s - loss: 0.1218 - 1s/epoch - 65ms/step
# Epoch 549/2000
# 16/16 - 1s - loss: 0.1212 - 1s/epoch - 64ms/step
# Epoch 550/2000
# 16/16 - 1s - loss: 0.1216 - 1s/epoch - 65ms/step
# Epoch 551/2000
# 16/16 - 1s - loss: 0.1210 - 1s/epoch - 65ms/step
# Epoch 552/2000
# 16/16 - 1s - loss: 0.1210 - 1s/epoch - 65ms/step
# Epoch 553/2000
# 16/16 - 1s - loss: 0.1202 - 1s/epoch - 65ms/step
# Epoch 554/2000
# 16/16 - 1s - loss: 0.1204 - 1s/epoch - 64ms/step
# Epoch 555/2000
# 16/16 - 1s - loss: 0.1203 - 1s/epoch - 65ms/step
# Epoch 556/2000
# 16/16 - 1s - loss: 0.1197 - 1s/epoch - 65ms/step
# Epoch 557/2000
# 16/16 - 1s - loss: 0.1193 - 1s/epoch - 65ms/step
# Epoch 558/2000
# 16/16 - 1s - loss: 0.1204 - 1s/epoch - 65ms/step
# Epoch 559/2000
# 16/16 - 1s - loss: 0.1201 - 1s/epoch - 65ms/step
# Epoch 560/2000
# 16/16 - 1s - loss: 0.1204 - 1s/epoch - 64ms/step
# Epoch 561/2000
# 16/16 - 1s - loss: 0.1225 - 1s/epoch - 65ms/step
# Epoch 562/2000
# 16/16 - 1s - loss: 0.1231 - 1s/epoch - 64ms/step
# Epoch 563/2000
# 16/16 - 1s - loss: 0.1257 - 1s/epoch - 65ms/step
# Epoch 564/2000
# 16/16 - 1s - loss: 0.1285 - 1s/epoch - 65ms/step
# Epoch 565/2000
# 16/16 - 1s - loss: 0.1316 - 1s/epoch - 66ms/step
# Epoch 566/2000
# 16/16 - 1s - loss: 0.1348 - 1s/epoch - 75ms/step
# Epoch 567/2000
# 16/16 - 1s - loss: 0.1378 - 1s/epoch - 65ms/step
# Epoch 568/2000
# 16/16 - 1s - loss: 0.1431 - 1s/epoch - 65ms/step
# Epoch 569/2000
# 16/16 - 1s - loss: 0.1513 - 1s/epoch - 69ms/step
# Epoch 570/2000
# 16/16 - 1s - loss: 0.1606 - 1s/epoch - 66ms/step
# Epoch 571/2000
# 16/16 - 1s - loss: 0.1718 - 1s/epoch - 64ms/step
# Epoch 572/2000
# 16/16 - 1s - loss: 0.1790 - 1s/epoch - 65ms/step
# Epoch 573/2000
# 16/16 - 1s - loss: 0.1818 - 1s/epoch - 69ms/step
# Epoch 574/2000
# 16/16 - 1s - loss: 0.1756 - 1s/epoch - 65ms/step
# Epoch 575/2000
# 16/16 - 1s - loss: 0.1664 - 1s/epoch - 65ms/step
# Epoch 576/2000
# 16/16 - 1s - loss: 0.1521 - 1s/epoch - 65ms/step
# Epoch 577/2000
# 16/16 - 1s - loss: 0.1437 - 1s/epoch - 65ms/step
# Epoch 578/2000
# 16/16 - 1s - loss: 0.1352 - 1s/epoch - 64ms/step
# Epoch 579/2000
# 16/16 - 1s - loss: 0.1286 - 1s/epoch - 65ms/step
# Epoch 580/2000
# 16/16 - 1s - loss: 0.1252 - 1s/epoch - 64ms/step
# Epoch 581/2000
# 16/16 - 1s - loss: 0.1215 - 1s/epoch - 65ms/step
# Epoch 582/2000
# 16/16 - 1s - loss: 0.1188 - 1s/epoch - 64ms/step
# Epoch 583/2000
# 16/16 - 1s - loss: 0.1178 - 1s/epoch - 64ms/step
# Epoch 584/2000
# 16/16 - 1s - loss: 0.1154 - 1s/epoch - 64ms/step
# Epoch 585/2000
# 16/16 - 1s - loss: 0.1141 - 1s/epoch - 65ms/step
# Epoch 586/2000
# 16/16 - 1s - loss: 0.1120 - 1s/epoch - 64ms/step
# Epoch 587/2000
# 16/16 - 1s - loss: 0.1110 - 1s/epoch - 65ms/step
# Epoch 588/2000
# 16/16 - 1s - loss: 0.1115 - 1s/epoch - 66ms/step
# Epoch 589/2000
# 16/16 - 1s - loss: 0.1099 - 1s/epoch - 64ms/step
# Epoch 590/2000
# 16/16 - 1s - loss: 0.1098 - 1s/epoch - 65ms/step
# Epoch 591/2000
# 16/16 - 1s - loss: 0.1087 - 1s/epoch - 65ms/step
# Epoch 592/2000
# 16/16 - 1s - loss: 0.1083 - 1s/epoch - 65ms/step
# Epoch 593/2000
# 16/16 - 1s - loss: 0.1082 - 1s/epoch - 66ms/step
# Epoch 594/2000
# 16/16 - 1s - loss: 0.1069 - 1s/epoch - 66ms/step
# Epoch 595/2000
# 16/16 - 1s - loss: 0.1070 - 1s/epoch - 74ms/step
# Epoch 596/2000
# 16/16 - 1s - loss: 0.1053 - 1s/epoch - 65ms/step
# Epoch 597/2000
# 16/16 - 1s - loss: 0.1053 - 1s/epoch - 65ms/step
# Epoch 598/2000
# 16/16 - 1s - loss: 0.1048 - 1s/epoch - 65ms/step
# Epoch 599/2000
# 16/16 - 1s - loss: 0.1046 - 1s/epoch - 64ms/step
# Epoch 600/2000
# 16/16 - 1s - loss: 0.1042 - 1s/epoch - 64ms/step
# Epoch 601/2000
# 16/16 - 1s - loss: 0.1042 - 1s/epoch - 66ms/step
# Epoch 602/2000
# 16/16 - 1s - loss: 0.1035 - 1s/epoch - 64ms/step
# Epoch 603/2000
# 16/16 - 1s - loss: 0.1031 - 1s/epoch - 65ms/step
# Epoch 604/2000
# 16/16 - 1s - loss: 0.1033 - 1s/epoch - 65ms/step
# Epoch 605/2000
# 16/16 - 1s - loss: 0.1023 - 1s/epoch - 65ms/step
# Epoch 606/2000
# 16/16 - 1s - loss: 0.1026 - 1s/epoch - 65ms/step
# Epoch 607/2000
# 16/16 - 1s - loss: 0.1029 - 1s/epoch - 66ms/step
# Epoch 608/2000
# 16/16 - 1s - loss: 0.1021 - 1s/epoch - 65ms/step
# Epoch 609/2000
# 16/16 - 1s - loss: 0.1021 - 1s/epoch - 64ms/step
# Epoch 610/2000
# 16/16 - 1s - loss: 0.1015 - 1s/epoch - 64ms/step
# Epoch 611/2000
# 16/16 - 1s - loss: 0.1025 - 1s/epoch - 65ms/step
# Epoch 612/2000
# 16/16 - 1s - loss: 0.1022 - 1s/epoch - 65ms/step
# Epoch 613/2000
# 16/16 - 1s - loss: 0.1029 - 1s/epoch - 65ms/step
# Epoch 614/2000
# 16/16 - 1s - loss: 0.1040 - 1s/epoch - 65ms/step
# Epoch 615/2000
# 16/16 - 1s - loss: 0.1053 - 1s/epoch - 65ms/step
# Epoch 616/2000
# 16/16 - 1s - loss: 0.1062 - 1s/epoch - 65ms/step
# Epoch 617/2000
# 16/16 - 1s - loss: 0.1092 - 1s/epoch - 65ms/step
# Epoch 618/2000
# 16/16 - 1s - loss: 0.1119 - 1s/epoch - 65ms/step
# Epoch 619/2000
# 16/16 - 1s - loss: 0.1158 - 1s/epoch - 64ms/step
# Epoch 620/2000
# 16/16 - 1s - loss: 0.1213 - 1s/epoch - 65ms/step
# Epoch 621/2000
# 16/16 - 1s - loss: 0.1260 - 1s/epoch - 68ms/step
# Epoch 622/2000
# 16/16 - 1s - loss: 0.1350 - 1s/epoch - 69ms/step
# Epoch 623/2000
# 16/16 - 1s - loss: 0.1460 - 1s/epoch - 65ms/step
# Epoch 624/2000
# 16/16 - 1s - loss: 0.1570 - 1s/epoch - 71ms/step
# Epoch 625/2000
# 16/16 - 1s - loss: 0.1662 - 1s/epoch - 65ms/step
# Epoch 626/2000
# 16/16 - 1s - loss: 0.1681 - 1s/epoch - 65ms/step
# Epoch 627/2000
# 16/16 - 1s - loss: 0.1696 - 1s/epoch - 65ms/step
# Epoch 628/2000
# 16/16 - 1s - loss: 0.1544 - 1s/epoch - 65ms/step
# Epoch 629/2000
# 16/16 - 1s - loss: 0.1420 - 1s/epoch - 65ms/step
# Epoch 630/2000
# 16/16 - 1s - loss: 0.1303 - 1s/epoch - 70ms/step
# Epoch 631/2000
# 16/16 - 1s - loss: 0.1205 - 1s/epoch - 68ms/step
# Epoch 632/2000
# 16/16 - 1s - loss: 0.1153 - 1s/epoch - 65ms/step
# Epoch 633/2000
# 16/16 - 1s - loss: 0.1078 - 1s/epoch - 65ms/step
# Epoch 634/2000
# 16/16 - 1s - loss: 0.1048 - 1s/epoch - 64ms/step
# Epoch 635/2000
# 16/16 - 1s - loss: 0.1021 - 1s/epoch - 65ms/step
# Epoch 636/2000
# 16/16 - 1s - loss: 0.1011 - 1s/epoch - 66ms/step
# Epoch 637/2000
# 16/16 - 1s - loss: 0.0995 - 1s/epoch - 65ms/step
# Epoch 638/2000
# 16/16 - 1s - loss: 0.0990 - 1s/epoch - 65ms/step
# Epoch 639/2000
# 16/16 - 1s - loss: 0.0968 - 1s/epoch - 65ms/step
# Epoch 640/2000
# 16/16 - 1s - loss: 0.0966 - 1s/epoch - 65ms/step
# Epoch 641/2000
# 16/16 - 1s - loss: 0.0953 - 1s/epoch - 65ms/step
# Epoch 642/2000
# 16/16 - 1s - loss: 0.0952 - 1s/epoch - 65ms/step
# Epoch 643/2000
# 16/16 - 1s - loss: 0.0955 - 1s/epoch - 65ms/step
# Epoch 644/2000
# 16/16 - 1s - loss: 0.0941 - 1s/epoch - 65ms/step
# Epoch 645/2000
# 16/16 - 1s - loss: 0.0934 - 1s/epoch - 64ms/step
# Epoch 646/2000
# 16/16 - 1s - loss: 0.0934 - 1s/epoch - 65ms/step
# Epoch 647/2000
# 16/16 - 1s - loss: 0.0928 - 1s/epoch - 65ms/step
# Epoch 648/2000
# 16/16 - 1s - loss: 0.0919 - 1s/epoch - 66ms/step
# Epoch 649/2000
# 16/16 - 1s - loss: 0.0927 - 1s/epoch - 67ms/step
# Epoch 650/2000
# 16/16 - 1s - loss: 0.0919 - 1s/epoch - 65ms/step
# Epoch 651/2000
# 16/16 - 1s - loss: 0.0914 - 1s/epoch - 65ms/step
# Epoch 652/2000
# 16/16 - 1s - loss: 0.0914 - 1s/epoch - 74ms/step
# Epoch 653/2000
# 16/16 - 1s - loss: 0.0910 - 1s/epoch - 69ms/step
# Epoch 654/2000
# 16/16 - 1s - loss: 0.0909 - 1s/epoch - 65ms/step
# Epoch 655/2000
# 16/16 - 1s - loss: 0.0903 - 1s/epoch - 65ms/step
# Epoch 656/2000
# 16/16 - 1s - loss: 0.0905 - 1s/epoch - 64ms/step
# Epoch 657/2000
# 16/16 - 1s - loss: 0.0900 - 1s/epoch - 65ms/step
# Epoch 658/2000
# 16/16 - 1s - loss: 0.0901 - 1s/epoch - 64ms/step
# Epoch 659/2000
# 16/16 - 1s - loss: 0.0894 - 1s/epoch - 64ms/step
# Epoch 660/2000
# 16/16 - 1s - loss: 0.0893 - 1s/epoch - 65ms/step
# Epoch 661/2000
# 16/16 - 1s - loss: 0.0884 - 1s/epoch - 65ms/step
# Epoch 662/2000
# 16/16 - 1s - loss: 0.0881 - 1s/epoch - 65ms/step
# Epoch 663/2000
# 16/16 - 1s - loss: 0.0889 - 1s/epoch - 65ms/step
# Epoch 664/2000
# 16/16 - 1s - loss: 0.0889 - 1s/epoch - 65ms/step
# Epoch 665/2000
# 16/16 - 1s - loss: 0.0907 - 1s/epoch - 65ms/step
# Epoch 666/2000
# 16/16 - 1s - loss: 0.0900 - 1s/epoch - 65ms/step
# Epoch 667/2000
# 16/16 - 1s - loss: 0.0911 - 1s/epoch - 65ms/step
# Epoch 668/2000
# 16/16 - 1s - loss: 0.0918 - 1s/epoch - 65ms/step
# Epoch 669/2000
# 16/16 - 1s - loss: 0.0904 - 1s/epoch - 65ms/step
# Epoch 670/2000
# 16/16 - 1s - loss: 0.0918 - 1s/epoch - 65ms/step
# Epoch 671/2000
# 16/16 - 1s - loss: 0.0923 - 1s/epoch - 64ms/step
# Epoch 672/2000
# 16/16 - 1s - loss: 0.0943 - 1s/epoch - 65ms/step
# Epoch 673/2000
# 16/16 - 1s - loss: 0.0931 - 1s/epoch - 65ms/step
# Epoch 674/2000
# 16/16 - 1s - loss: 0.0949 - 1s/epoch - 65ms/step
# Epoch 675/2000
# 16/16 - 1s - loss: 0.0987 - 1s/epoch - 65ms/step
# Epoch 676/2000
# 16/16 - 1s - loss: 0.1014 - 1s/epoch - 65ms/step
# Epoch 677/2000
# 16/16 - 1s - loss: 0.1053 - 1s/epoch - 65ms/step
# Epoch 678/2000
# 16/16 - 1s - loss: 0.1089 - 1s/epoch - 65ms/step
# Epoch 679/2000
# 16/16 - 1s - loss: 0.1134 - 1s/epoch - 65ms/step
# Epoch 680/2000
# 16/16 - 1s - loss: 0.1193 - 1s/epoch - 65ms/step
# Epoch 681/2000
# 16/16 - 1s - loss: 0.1237 - 1s/epoch - 75ms/step
# Epoch 682/2000
# 16/16 - 1s - loss: 0.1244 - 1s/epoch - 65ms/step
# Epoch 683/2000
# 16/16 - 1s - loss: 0.1314 - 1s/epoch - 65ms/step
# Epoch 684/2000
# 16/16 - 1s - loss: 0.1344 - 1s/epoch - 65ms/step
# Epoch 685/2000
# 16/16 - 1s - loss: 0.1287 - 1s/epoch - 66ms/step
# Epoch 686/2000
# 16/16 - 1s - loss: 0.1245 - 1s/epoch - 65ms/step
# Epoch 687/2000
# 16/16 - 1s - loss: 0.1212 - 1s/epoch - 65ms/step
# Epoch 688/2000
# 16/16 - 1s - loss: 0.1150 - 1s/epoch - 64ms/step
# Epoch 689/2000
# 16/16 - 1s - loss: 0.1112 - 1s/epoch - 65ms/step
# Epoch 690/2000
# 16/16 - 1s - loss: 0.1048 - 1s/epoch - 65ms/step
# Epoch 691/2000
# 16/16 - 1s - loss: 0.0990 - 1s/epoch - 65ms/step
# Epoch 692/2000
# 16/16 - 1s - loss: 0.0959 - 1s/epoch - 65ms/step
# Epoch 693/2000
# 16/16 - 1s - loss: 0.0934 - 1s/epoch - 64ms/step
# Epoch 694/2000
# 16/16 - 1s - loss: 0.0917 - 1s/epoch - 65ms/step
# Epoch 695/2000
# 16/16 - 1s - loss: 0.0905 - 1s/epoch - 65ms/step
# Epoch 696/2000
# 16/16 - 1s - loss: 0.0877 - 1s/epoch - 65ms/step
# Epoch 697/2000
# 16/16 - 1s - loss: 0.0868 - 1s/epoch - 66ms/step
# Epoch 698/2000
# 16/16 - 1s - loss: 0.0861 - 1s/epoch - 65ms/step
# Epoch 699/2000
# 16/16 - 1s - loss: 0.0852 - 1s/epoch - 65ms/step
# Epoch 700/2000
# 16/16 - 1s - loss: 0.0846 - 1s/epoch - 65ms/step
# Epoch 701/2000
# 16/16 - 1s - loss: 0.0845 - 1s/epoch - 65ms/step
# Epoch 702/2000
# 16/16 - 1s - loss: 0.0837 - 1s/epoch - 65ms/step
# Epoch 703/2000
# 16/16 - 1s - loss: 0.0836 - 1s/epoch - 65ms/step
# Epoch 704/2000
# 16/16 - 1s - loss: 0.0833 - 1s/epoch - 65ms/step
# Epoch 705/2000
# 16/16 - 1s - loss: 0.0835 - 1s/epoch - 66ms/step
# Epoch 706/2000
# 16/16 - 1s - loss: 0.0825 - 1s/epoch - 65ms/step
# Epoch 707/2000
# 16/16 - 1s - loss: 0.0830 - 1s/epoch - 65ms/step
# Epoch 708/2000
# 16/16 - 1s - loss: 0.0826 - 1s/epoch - 65ms/step
# Epoch 709/2000
# 16/16 - 1s - loss: 0.0817 - 1s/epoch - 65ms/step
# Epoch 710/2000
# 16/16 - 1s - loss: 0.0810 - 1s/epoch - 73ms/step
# Epoch 711/2000
# 16/16 - 1s - loss: 0.0820 - 1s/epoch - 65ms/step
# Epoch 712/2000
# 16/16 - 1s - loss: 0.0814 - 1s/epoch - 65ms/step
# Epoch 713/2000
# 16/16 - 1s - loss: 0.0818 - 1s/epoch - 67ms/step
# Epoch 714/2000
# 16/16 - 1s - loss: 0.0806 - 1s/epoch - 65ms/step
# Epoch 715/2000
# 16/16 - 1s - loss: 0.0808 - 1s/epoch - 64ms/step
# Epoch 716/2000
# 16/16 - 1s - loss: 0.0807 - 1s/epoch - 65ms/step
# Epoch 717/2000
# 16/16 - 1s - loss: 0.0805 - 1s/epoch - 65ms/step
# Epoch 718/2000
# 16/16 - 1s - loss: 0.0813 - 1s/epoch - 64ms/step
# Epoch 719/2000
# 16/16 - 1s - loss: 0.0816 - 1s/epoch - 65ms/step
# Epoch 720/2000
# 16/16 - 1s - loss: 0.0810 - 1s/epoch - 65ms/step
# Epoch 721/2000
# 16/16 - 1s - loss: 0.0806 - 1s/epoch - 66ms/step
# Epoch 722/2000
# 16/16 - 1s - loss: 0.0821 - 1s/epoch - 65ms/step
# Epoch 723/2000
# 16/16 - 1s - loss: 0.0835 - 1s/epoch - 65ms/step
# Epoch 724/2000
# 16/16 - 1s - loss: 0.0830 - 1s/epoch - 65ms/step
# Epoch 725/2000
# 16/16 - 1s - loss: 0.0831 - 1s/epoch - 65ms/step
# Epoch 726/2000
# 16/16 - 1s - loss: 0.0835 - 1s/epoch - 65ms/step
# Epoch 727/2000
# 16/16 - 1s - loss: 0.0833 - 1s/epoch - 64ms/step
# Epoch 728/2000
# 16/16 - 1s - loss: 0.0860 - 1s/epoch - 65ms/step
# Epoch 729/2000
# 16/16 - 1s - loss: 0.0879 - 1s/epoch - 66ms/step
# Epoch 730/2000
# 16/16 - 1s - loss: 0.0886 - 1s/epoch - 66ms/step
# Epoch 731/2000
# 16/16 - 1s - loss: 0.0931 - 1s/epoch - 65ms/step
# Epoch 732/2000
# 16/16 - 1s - loss: 0.0953 - 1s/epoch - 68ms/step
# Epoch 733/2000
# 16/16 - 1s - loss: 0.0960 - 1s/epoch - 66ms/step
# Epoch 734/2000
# 16/16 - 1s - loss: 0.1001 - 1s/epoch - 65ms/step
# Epoch 735/2000
# 16/16 - 1s - loss: 0.1038 - 1s/epoch - 65ms/step
# Epoch 736/2000
# 16/16 - 1s - loss: 0.1067 - 1s/epoch - 64ms/step
# Epoch 737/2000
# 16/16 - 1s - loss: 0.1078 - 1s/epoch - 65ms/step
# Epoch 738/2000
# 16/16 - 1s - loss: 0.1127 - 1s/epoch - 69ms/step
# Epoch 739/2000
# 16/16 - 1s - loss: 0.1133 - 1s/epoch - 73ms/step
# Epoch 740/2000
# 16/16 - 1s - loss: 0.1113 - 1s/epoch - 65ms/step
# Epoch 741/2000
# 16/16 - 1s - loss: 0.1056 - 1s/epoch - 68ms/step
# Epoch 742/2000
# 16/16 - 1s - loss: 0.1008 - 1s/epoch - 65ms/step
# Epoch 743/2000
# 16/16 - 1s - loss: 0.0957 - 1s/epoch - 64ms/step
# Epoch 744/2000
# 16/16 - 1s - loss: 0.0919 - 1s/epoch - 64ms/step
# Epoch 745/2000
# 16/16 - 1s - loss: 0.0883 - 1s/epoch - 65ms/step
# Epoch 746/2000
# 16/16 - 1s - loss: 0.0848 - 1s/epoch - 64ms/step
# Epoch 747/2000
# 16/16 - 1s - loss: 0.0832 - 1s/epoch - 64ms/step
# Epoch 748/2000
# 16/16 - 1s - loss: 0.0820 - 1s/epoch - 66ms/step
# Epoch 749/2000
# 16/16 - 1s - loss: 0.0810 - 1s/epoch - 65ms/step
# Epoch 750/2000
# 16/16 - 1s - loss: 0.0793 - 1s/epoch - 65ms/step
# Epoch 751/2000
# 16/16 - 1s - loss: 0.0782 - 1s/epoch - 65ms/step
# Epoch 752/2000
# ...
# Epoch 1755/2000
# 16/16 - 1s - loss: 0.0439 - 1s/epoch - 65ms/step
# Epoch 1756/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1757/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1758/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 74ms/step
# Epoch 1759/2000
# 16/16 - 1s - loss: 0.0439 - 1s/epoch - 72ms/step
# Epoch 1760/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step
# Epoch 1761/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 67ms/step
# Epoch 1762/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1763/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1764/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 65ms/step
# Epoch 1765/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 73ms/step
# Epoch 1766/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1767/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1768/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1769/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 64ms/step
# Epoch 1770/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1771/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 68ms/step
# Epoch 1772/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1773/2000
# 16/16 - 1s - loss: 0.0426 - 1s/epoch - 65ms/step
# Epoch 1774/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1775/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step
# Epoch 1776/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1777/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1778/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 65ms/step
# Epoch 1779/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 65ms/step
# Epoch 1780/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1781/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1782/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 64ms/step
# Epoch 1783/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 64ms/step
# Epoch 1784/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 65ms/step
# Epoch 1785/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 64ms/step
# Epoch 1786/2000
# 16/16 - 1s - loss: 0.0438 - 1s/epoch - 68ms/step
# Epoch 1787/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 72ms/step
# Epoch 1788/2000
# 16/16 - 1s - loss: 0.0442 - 1s/epoch - 65ms/step
# Epoch 1789/2000
# 16/16 - 1s - loss: 0.0439 - 1s/epoch - 69ms/step
# Epoch 1790/2000
# 16/16 - 1s - loss: 0.0443 - 1s/epoch - 65ms/step
# Epoch 1791/2000
# 16/16 - 1s - loss: 0.0445 - 1s/epoch - 65ms/step
# Epoch 1792/2000
# 16/16 - 1s - loss: 0.0448 - 1s/epoch - 65ms/step
# Epoch 1793/2000
# 16/16 - 1s - loss: 0.0447 - 1s/epoch - 67ms/step
# Epoch 1794/2000
# 16/16 - 1s - loss: 0.0459 - 1s/epoch - 65ms/step
# Epoch 1795/2000
# 16/16 - 1s - loss: 0.0460 - 1s/epoch - 66ms/step
# Epoch 1796/2000
# 16/16 - 1s - loss: 0.0478 - 1s/epoch - 64ms/step
# Epoch 1797/2000
# 16/16 - 1s - loss: 0.0496 - 1s/epoch - 64ms/step
# Epoch 1798/2000
# 16/16 - 1s - loss: 0.0511 - 1s/epoch - 65ms/step
# Epoch 1799/2000
# 16/16 - 1s - loss: 0.0506 - 1s/epoch - 65ms/step
# Epoch 1800/2000
# 16/16 - 1s - loss: 0.0519 - 1s/epoch - 65ms/step
# Epoch 1801/2000
# 16/16 - 1s - loss: 0.0529 - 1s/epoch - 65ms/step
# Epoch 1802/2000
# 16/16 - 1s - loss: 0.0550 - 1s/epoch - 65ms/step
# Epoch 1803/2000
# 16/16 - 1s - loss: 0.0544 - 1s/epoch - 65ms/step
# Epoch 1804/2000
# 16/16 - 1s - loss: 0.0525 - 1s/epoch - 65ms/step
# Epoch 1805/2000
# 16/16 - 1s - loss: 0.0544 - 1s/epoch - 65ms/step
# Epoch 1806/2000
# 16/16 - 1s - loss: 0.0522 - 1s/epoch - 65ms/step
# Epoch 1807/2000
# 16/16 - 1s - loss: 0.0508 - 1s/epoch - 65ms/step
# Epoch 1808/2000
# 16/16 - 1s - loss: 0.0493 - 1s/epoch - 65ms/step
# Epoch 1809/2000
# 16/16 - 1s - loss: 0.0479 - 1s/epoch - 66ms/step
# Epoch 1810/2000
# 16/16 - 1s - loss: 0.0471 - 1s/epoch - 65ms/step
# Epoch 1811/2000
# 16/16 - 1s - loss: 0.0461 - 1s/epoch - 64ms/step
# Epoch 1812/2000
# 16/16 - 1s - loss: 0.0456 - 1s/epoch - 65ms/step
# Epoch 1813/2000
# 16/16 - 1s - loss: 0.0449 - 1s/epoch - 65ms/step
# Epoch 1814/2000
# 16/16 - 1s - loss: 0.0449 - 1s/epoch - 65ms/step
# Epoch 1815/2000
# 16/16 - 1s - loss: 0.0439 - 1s/epoch - 72ms/step
# Epoch 1816/2000
# 16/16 - 1s - loss: 0.0442 - 1s/epoch - 69ms/step
# Epoch 1817/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 65ms/step
# Epoch 1818/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1819/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1820/2000
# 16/16 - 1s - loss: 0.0441 - 1s/epoch - 68ms/step
# Epoch 1821/2000
# 16/16 - 1s - loss: 0.0438 - 1s/epoch - 64ms/step
# Epoch 1822/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1823/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 65ms/step
# Epoch 1824/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1825/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1826/2000
# 16/16 - 1s - loss: 0.0439 - 1s/epoch - 65ms/step
# Epoch 1827/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1828/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1829/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1830/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 65ms/step
# Epoch 1831/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1832/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1833/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step
# Epoch 1834/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1835/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1836/2000
# 16/16 - 1s - loss: 0.0426 - 1s/epoch - 64ms/step
# Epoch 1837/2000
# 16/16 - 1s - loss: 0.0423 - 1s/epoch - 65ms/step
# Epoch 1838/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1839/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1840/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 64ms/step
# Epoch 1841/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1842/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 66ms/step
# Epoch 1843/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 74ms/step
# Epoch 1844/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 65ms/step
# Epoch 1845/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step
# Epoch 1846/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1847/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1848/2000
# 16/16 - 1s - loss: 0.0425 - 1s/epoch - 67ms/step
# Epoch 1849/2000
# 16/16 - 1s - loss: 0.0421 - 1s/epoch - 64ms/step
# Epoch 1850/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1851/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1852/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 66ms/step
# Epoch 1853/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 64ms/step
# Epoch 1854/2000
# 16/16 - 1s - loss: 0.0435 - 1s/epoch - 65ms/step
# Epoch 1855/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1856/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1857/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1858/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1859/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1860/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 65ms/step
# Epoch 1861/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1862/2000
# 16/16 - 1s - loss: 0.0426 - 1s/epoch - 65ms/step
# Epoch 1863/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1864/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 65ms/step
# Epoch 1865/2000
# 16/16 - 1s - loss: 0.0438 - 1s/epoch - 66ms/step
# Epoch 1866/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1867/2000
# 16/16 - 1s - loss: 0.0441 - 1s/epoch - 65ms/step
# Epoch 1868/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 64ms/step
# Epoch 1869/2000
# 16/16 - 1s - loss: 0.0447 - 1s/epoch - 65ms/step
# Epoch 1870/2000
# 16/16 - 1s - loss: 0.0449 - 1s/epoch - 65ms/step
# Epoch 1871/2000
# 16/16 - 1s - loss: 0.0452 - 1s/epoch - 72ms/step
# Epoch 1872/2000
# 16/16 - 1s - loss: 0.0457 - 1s/epoch - 73ms/step
# Epoch 1873/2000
# 16/16 - 1s - loss: 0.0453 - 1s/epoch - 65ms/step
# Epoch 1874/2000
# 16/16 - 1s - loss: 0.0468 - 1s/epoch - 65ms/step
# Epoch 1875/2000
# 16/16 - 1s - loss: 0.0461 - 1s/epoch - 64ms/step
# Epoch 1876/2000
# 16/16 - 1s - loss: 0.0470 - 1s/epoch - 67ms/step
# Epoch 1877/2000
# 16/16 - 1s - loss: 0.0474 - 1s/epoch - 64ms/step
# Epoch 1878/2000
# 16/16 - 1s - loss: 0.0488 - 1s/epoch - 64ms/step
# Epoch 1879/2000
# 16/16 - 1s - loss: 0.0487 - 1s/epoch - 65ms/step
# Epoch 1880/2000
# 16/16 - 1s - loss: 0.0486 - 1s/epoch - 64ms/step
# Epoch 1881/2000
# 16/16 - 1s - loss: 0.0507 - 1s/epoch - 65ms/step
# Epoch 1882/2000
# 16/16 - 1s - loss: 0.0509 - 1s/epoch - 65ms/step
# Epoch 1883/2000
# 16/16 - 1s - loss: 0.0527 - 1s/epoch - 65ms/step
# Epoch 1884/2000
# 16/16 - 1s - loss: 0.0522 - 1s/epoch - 65ms/step
# Epoch 1885/2000
# 16/16 - 1s - loss: 0.0506 - 1s/epoch - 65ms/step
# Epoch 1886/2000
# 16/16 - 1s - loss: 0.0521 - 1s/epoch - 65ms/step
# Epoch 1887/2000
# 16/16 - 1s - loss: 0.0515 - 1s/epoch - 64ms/step
# Epoch 1888/2000
# 16/16 - 1s - loss: 0.0502 - 1s/epoch - 65ms/step
# Epoch 1889/2000
# 16/16 - 1s - loss: 0.0490 - 1s/epoch - 65ms/step
# Epoch 1890/2000
# 16/16 - 1s - loss: 0.0489 - 1s/epoch - 65ms/step
# Epoch 1891/2000
# 16/16 - 1s - loss: 0.0469 - 1s/epoch - 65ms/step
# Epoch 1892/2000
# 16/16 - 1s - loss: 0.0463 - 1s/epoch - 65ms/step
# Epoch 1893/2000
# 16/16 - 1s - loss: 0.0464 - 1s/epoch - 64ms/step
# Epoch 1894/2000
# 16/16 - 1s - loss: 0.0462 - 1s/epoch - 65ms/step
# Epoch 1895/2000
# 16/16 - 1s - loss: 0.0454 - 1s/epoch - 65ms/step
# Epoch 1896/2000
# 16/16 - 1s - loss: 0.0443 - 1s/epoch - 65ms/step
# Epoch 1897/2000
# 16/16 - 1s - loss: 0.0444 - 1s/epoch - 65ms/step
# Epoch 1898/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 65ms/step
# Epoch 1899/2000
# 16/16 - 1s - loss: 0.0425 - 1s/epoch - 66ms/step
# Epoch 1900/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 75ms/step
# Epoch 1901/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1902/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1903/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 64ms/step
# Epoch 1904/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 68ms/step
# Epoch 1905/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1906/2000
# 16/16 - 1s - loss: 0.0426 - 1s/epoch - 65ms/step
# Epoch 1907/2000
# 16/16 - 1s - loss: 0.0422 - 1s/epoch - 65ms/step
# Epoch 1908/2000
# 16/16 - 1s - loss: 0.0424 - 1s/epoch - 65ms/step
# Epoch 1909/2000
# 16/16 - 1s - loss: 0.0426 - 1s/epoch - 65ms/step
# Epoch 1910/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1911/2000
# 16/16 - 1s - loss: 0.0425 - 1s/epoch - 65ms/step
# Epoch 1912/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1913/2000
# 16/16 - 1s - loss: 0.0422 - 1s/epoch - 65ms/step
# Epoch 1914/2000
# 16/16 - 1s - loss: 0.0421 - 1s/epoch - 65ms/step
# Epoch 1915/2000
# 16/16 - 1s - loss: 0.0422 - 1s/epoch - 65ms/step
# Epoch 1916/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1917/2000
# 16/16 - 1s - loss: 0.0419 - 1s/epoch - 65ms/step
# Epoch 1918/2000
# 16/16 - 1s - loss: 0.0418 - 1s/epoch - 65ms/step
# Epoch 1919/2000
# 16/16 - 1s - loss: 0.0416 - 1s/epoch - 65ms/step
# Epoch 1920/2000
# 16/16 - 1s - loss: 0.0423 - 1s/epoch - 64ms/step
# Epoch 1921/2000
# 16/16 - 1s - loss: 0.0423 - 1s/epoch - 64ms/step
# Epoch 1922/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1923/2000
# 16/16 - 1s - loss: 0.0423 - 1s/epoch - 68ms/step
# Epoch 1924/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1925/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 65ms/step
# Epoch 1926/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 66ms/step
# Epoch 1927/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 73ms/step
# Epoch 1928/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1929/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 64ms/step
# Epoch 1930/2000
# 16/16 - 1s - loss: 0.0424 - 1s/epoch - 65ms/step
# Epoch 1931/2000
# 16/16 - 1s - loss: 0.0420 - 1s/epoch - 71ms/step
# Epoch 1932/2000
# 16/16 - 1s - loss: 0.0425 - 1s/epoch - 65ms/step
# Epoch 1933/2000
# 16/16 - 1s - loss: 0.0424 - 1s/epoch - 65ms/step
# Epoch 1934/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1935/2000
# 16/16 - 1s - loss: 0.0424 - 1s/epoch - 64ms/step
# Epoch 1936/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 64ms/step
# Epoch 1937/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 65ms/step
# Epoch 1938/2000
# 16/16 - 1s - loss: 0.0426 - 1s/epoch - 65ms/step
# Epoch 1939/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 65ms/step
# Epoch 1940/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 66ms/step
# Epoch 1941/2000
# 16/16 - 1s - loss: 0.0438 - 1s/epoch - 64ms/step
# Epoch 1942/2000
# 16/16 - 1s - loss: 0.0439 - 1s/epoch - 64ms/step
# Epoch 1943/2000
# 16/16 - 1s - loss: 0.0441 - 1s/epoch - 65ms/step
# Epoch 1944/2000
# 16/16 - 1s - loss: 0.0442 - 1s/epoch - 65ms/step
# Epoch 1945/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 65ms/step
# Epoch 1946/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1947/2000
# 16/16 - 1s - loss: 0.0443 - 1s/epoch - 64ms/step
# Epoch 1948/2000
# 16/16 - 1s - loss: 0.0451 - 1s/epoch - 65ms/step
# Epoch 1949/2000
# 16/16 - 1s - loss: 0.0455 - 1s/epoch - 65ms/step
# Epoch 1950/2000
# 16/16 - 1s - loss: 0.0456 - 1s/epoch - 64ms/step
# Epoch 1951/2000
# 16/16 - 1s - loss: 0.0471 - 1s/epoch - 65ms/step
# Epoch 1952/2000
# 16/16 - 1s - loss: 0.0464 - 1s/epoch - 65ms/step
# Epoch 1953/2000
# 16/16 - 1s - loss: 0.0460 - 1s/epoch - 65ms/step
# Epoch 1954/2000
# 16/16 - 1s - loss: 0.0468 - 1s/epoch - 67ms/step
# Epoch 1955/2000
# 16/16 - 1s - loss: 0.0481 - 1s/epoch - 66ms/step
# Epoch 1956/2000
# 16/16 - 1s - loss: 0.0469 - 1s/epoch - 75ms/step
# Epoch 1957/2000
# 16/16 - 1s - loss: 0.0480 - 1s/epoch - 65ms/step
# Epoch 1958/2000
# 16/16 - 1s - loss: 0.0485 - 1s/epoch - 65ms/step
# Epoch 1959/2000
# 16/16 - 1s - loss: 0.0482 - 1s/epoch - 73ms/step
# Epoch 1960/2000
# 16/16 - 1s - loss: 0.0472 - 1s/epoch - 65ms/step
# Epoch 1961/2000
# 16/16 - 1s - loss: 0.0483 - 1s/epoch - 65ms/step
# Epoch 1962/2000
# 16/16 - 1s - loss: 0.0478 - 1s/epoch - 65ms/step
# Epoch 1963/2000
# 16/16 - 1s - loss: 0.0467 - 1s/epoch - 65ms/step
# Epoch 1964/2000
# 16/16 - 1s - loss: 0.0457 - 1s/epoch - 65ms/step
# Epoch 1965/2000
# 16/16 - 1s - loss: 0.0459 - 1s/epoch - 64ms/step
# Epoch 1966/2000
# 16/16 - 1s - loss: 0.0451 - 1s/epoch - 65ms/step
# Epoch 1967/2000
# 16/16 - 1s - loss: 0.0447 - 1s/epoch - 65ms/step
# Epoch 1968/2000
# 16/16 - 1s - loss: 0.0446 - 1s/epoch - 65ms/step
# Epoch 1969/2000
# 16/16 - 1s - loss: 0.0447 - 1s/epoch - 65ms/step
# Epoch 1970/2000
# 16/16 - 1s - loss: 0.0444 - 1s/epoch - 64ms/step
# Epoch 1971/2000
# 16/16 - 1s - loss: 0.0444 - 1s/epoch - 64ms/step
# Epoch 1972/2000
# 16/16 - 1s - loss: 0.0438 - 1s/epoch - 65ms/step
# Epoch 1973/2000
# 16/16 - 1s - loss: 0.0443 - 1s/epoch - 65ms/step
# Epoch 1974/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 65ms/step
# Epoch 1975/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 65ms/step
# Epoch 1976/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step
# Epoch 1977/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 64ms/step
# Epoch 1978/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1979/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 65ms/step
# Epoch 1980/2000
# 16/16 - 1s - loss: 0.0438 - 1s/epoch - 65ms/step
# Epoch 1981/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 66ms/step
# Epoch 1982/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 66ms/step
# Epoch 1983/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step
# Epoch 1984/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 72ms/step
# Epoch 1985/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 66ms/step
# Epoch 1986/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 72ms/step
# Epoch 1987/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1988/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 1989/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1990/2000
# 16/16 - 1s - loss: 0.0434 - 1s/epoch - 64ms/step
# Epoch 1991/2000
# 16/16 - 1s - loss: 0.0427 - 1s/epoch - 65ms/step
# Epoch 1992/2000
# 16/16 - 1s - loss: 0.0431 - 1s/epoch - 65ms/step
# Epoch 1993/2000
# 16/16 - 1s - loss: 0.0428 - 1s/epoch - 64ms/step
# Epoch 1994/2000
# 16/16 - 1s - loss: 0.0440 - 1s/epoch - 65ms/step
# Epoch 1995/2000
# 16/16 - 1s - loss: 0.0436 - 1s/epoch - 64ms/step
# Epoch 1996/2000
# 16/16 - 1s - loss: 0.0437 - 1s/epoch - 64ms/step
# Epoch 1997/2000
# 16/16 - 1s - loss: 0.0429 - 1s/epoch - 65ms/step
# Epoch 1998/2000
# 16/16 - 1s - loss: 0.0433 - 1s/epoch - 65ms/step
# Epoch 1999/2000
# 16/16 - 1s - loss: 0.0430 - 1s/epoch - 65ms/step
# Epoch 2000/2000
# 16/16 - 1s - loss: 0.0432 - 1s/epoch - 65ms/step

# %%
model.save_weights('my_model/kieu_gpt')

# %%
import json
idxs_from_chars_cfg = idxs_from_chars.get_config()
with open("idxs_lookup_config.json", "w") as outfile:
    json.dump(idxs_from_chars_cfg, outfile)
    
# tf.keras.layers.StringLookup(**idxs_from_chars_cfg)

# %% [markdown]
# # Generate text

# %%
class PoemTeller(tf.keras.Model):
    def __init__(self, model, chars_from_idxs, idxs_from_chars, temperature=1.0):
        super().__init__()
        self.temperature = temperature
        self.model = model
        self.chars_from_idxs = chars_from_idxs
        self.idxs_from_chars = idxs_from_chars

    @tf.function
    def generate_one_step(self, inputs, states=None):
        # Convert strings to token IDs.
        input_chars = tf.strings.unicode_split(inputs, 'UTF-8')
        input_ids = self.idxs_from_chars(input_chars).to_tensor()

        # Run the model.
        # predicted_logits.shape is [batch, char, next_char_logits]
        predicted_logits, states = self.model(inputs=input_ids, states=states,
                                            return_state=True)
        # Only use the last prediction.
        predicted_logits = predicted_logits[:, -1, :]
        predicted_logits = predicted_logits/self.temperature

        # Sample the output logits to generate token IDs.
        predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
        predicted_ids = tf.squeeze(predicted_ids, axis=-1)

        # Convert from token ids to characters
        predicted_chars = self.chars_from_idxs(predicted_ids)

        # Return the characters and model state.
        return predicted_chars, states

# %%
teller = PoemTeller(model, chars_from_idxs, idxs_from_chars, 0.1)

# %%
inp = "em"

lines = 10
start = time.time()
states = None
next_char = tf.constant([inp])
result = [next_char]

i=0
while i < lines:
    next_char, states = teller.generate_one_step(next_char, states=states)
    result.append(next_char)
    if next_char[0].numpy().decode('utf-8') == '\n':
        i += 1

result = tf.strings.join(result)
output_text = result[0].numpy().decode('utf-8')
end = time.time()
print(output_text, '\n\n' + '-'*80)
print('Run time:', end - start)
# Out:
# em
# tưng bừng sắm sửa áo xiêm
# biện dâng một lễ xa đem tấc thành
# nhà lan thanh vắng một mình
# ngẫm chần đồ đến ai lầu chương trời
# nôi then những thịnh trăng vài
# trời đâu bắng động tiện gười nhun dan
# xóc ngu tà mệt ai
# trong nhần đã thủ phận hồi cho ang
# đưa trầy chịp dau tơ đàn
#
#
# --------------------------------------------------------------------------------
# Run time: 1.9405808448791504
